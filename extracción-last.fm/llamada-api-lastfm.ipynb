# %%
import requests #librerias necesarias
import pandas as pd
import sys 
# sys.exit(1) detiene la ejecución del script INMEDIATAMENTE al encontrar un error
# CRÍTICO (como un archivo faltante o una columna incorrecta), evitando que el programa
# intente continuar y falle después. El número '1' indica que la terminación fue por un error.


apikey = "b4fcada0293085a139072e5e87a365b4"
url = "http://ws.audioscrobbler.com/2.0/"

# lectura de archivo csv
ruta_csv_artistas = '../csv/total_canciones_2018-2022.csv'
# recordamos usar rutas relativas para que funcione en todos los entornos locales

try:
    df_artistas = pd.read_csv(ruta_csv_artistas) #dataframe de artistas desde la ruta de lectura
    
    artistas_con_duplicados = df_artistas['artista'].tolist() #hacemos de 'artista' una lista
    
    artistas_unicos_set = set(artistas_con_duplicados) #con set eliminamos los duplicados
    
    artistas_a_buscar = list(artistas_unicos_set) #aqui ya tenemos la lista limpia con artistas unicos para poder analizar
    
    print(f"✅ Se cargaron {len(artistas_con_duplicados)} registros de artistas (incluidos duplicados).")
    print(f"✨ Se analizarán {len(artistas_a_buscar)} artistas únicos.")

except FileNotFoundError: #los except nos indican que tipo de errores se ha encontrado a la hora de cargar el csv
    print(f"❌ ERROR CRÍTICO: No se encontró el archivo CSV en la ruta '{ruta_csv_artistas}'.")
    sys.exit(1) # El código de salida 1 indica que hubo un error.

except KeyError:
    print(f"❌ ERROR CRÍTICO: La columna 'artista' no se encontró en el archivo CSV.")
    print("Por favor, verifica que el encabezado de la columna en el CSV se llame exactamente 'artista'.")
    sys.exit(1)

except Exception as e:
    print(f"❌ ERROR CRÍTICO: Ocurrió un error inesperado al leer el CSV: {e}")
    sys.exit(1)

# ----------------------------------------------------
# 📌 PUNTO 1: Inicializar la lista para guardar los datos
# ----------------------------------------------------
resultados_api = []
ruta_csv_salida = '../csv/datos_artistas_lastfm.csv' # Define la ruta y nombre del archivo de salida


#bucle para cargar todos los artistas (únicos)
for artista_actual in artistas_a_buscar:
    
    print(f"\n==================================================") #llamadas a la API
    print(f"🔎 Procesando artista: **{artista_actual}**")
    print(f"==================================================")

    # Inicializar un diccionario para los datos de este artista
    datos_artista = {"artista": artista_actual}
    
    #llamada para BIOGRAFIA
    params_info = { #estas lineas no se pueden modificar ya que son necesarias para que nos de la biografia completa
        "method": "artist.getInfo",
        "artist": artista_actual,
        "api_key": apikey,
        "format": "json",
        "autocorrect": 1
    }
    
    try:
        response_info = requests.get(url, params=params_info) 
        datos_info = response_info.json()

        if response_info.status_code == 200 and 'artist' in datos_info: #comprueba que la llamada haya sido exitosa
            info_artista = datos_info['artist']
            
            # --- Extracción y Guardado de datos de BIOGRAFÍA y ESTADÍSTICAS ---
            print("--- BIOGRAFÍA y ESTADÍSTICAS ---")
            biografia_corta = info_artista.get('bio', {}).get('summary', 'No disponible')
            biografia_limpia = biografia_corta.split('<a href')[0].strip()
            
            estadisticas = info_artista.get('stats', {})
            playcount = estadisticas.get('playcount')
            listeners = estadisticas.get('listeners')
            
            # 📌 PUNTO 2: Almacenar datos en el diccionario
            datos_artista['playcount'] = playcount
            datos_artista['listeners'] = listeners
            datos_artista['biografia_resumen'] = biografia_limpia
            
            print(f"Nombre: {info_artista.get('name')}")
            print(f"Biografía (Resumen): {biografia_limpia}")
            print(f"Playcount Total (Last.fm): {playcount}")
            print(f"Número de Oyentes Únicos: {listeners}")
            
        else:
            print(f"❌ Error al obtener info para {artista_actual}. Estado HTTP: {response_info.status_code}")
            datos_artista['playcount'] = None # Si falla, asignamos None para no dejar el campo vacío
            datos_artista['biografia_resumen'] = "API Error"
            
    except requests.RequestException as e:
        print(f"❌ Error de conexión al obtener info para {artista_actual}: {e}")
        datos_artista['playcount'] = None
        datos_artista['biografia_resumen'] = "Connection Error"


    # llamada artistas similares
    similares = {
        "method": "artist.getSimilar",
        "artist": artista_actual,
        "api_key": apikey,
        "format": "json",
        "limit": 5 # Obtener los 5 artistas más similares
    }
    
    # Inicializar la columna de similares
    datos_artista['similares'] = "" # Cadena vacía por defecto
    
    try:
        response_similar = requests.get(url, params=similares)
        datos_similar = response_similar.json()

        if response_similar.status_code == 200 and 'similarartists' in datos_similar:
            artistas_similares = datos_similar['similarartists']['artist']
            
            # Artistas Similares
            print("\n--- ARTISTAS SIMILARES ---")
            if artistas_similares:
                # Crear una lista de nombres de artistas similares y unirlos con coma
                nombres_similares = [similar.get('name') for similar in artistas_similares]
                datos_artista['similares'] = ", ".join(nombres_similares) # 📌 PUNTO 3: Guardar en el diccionario

                for i, similar in enumerate(artistas_similares):
                    print(f"{i+1}. {similar.get('name')} (Similitud: {similar.get('match')})")
            else:
                print("No se encontraron artistas similares.")
        else:
            print(f"❌ Error al obtener similares para {artista_actual}. Estado HTTP: {response_similar.status_code}")
            
    except requests.RequestException as e:
        print(f"❌ Error de conexión al obtener similares para {artista_actual}: {e}")

    # Añadir el diccionario de datos al listado general
    resultados_api.append(datos_artista)


#conversion a csv en el caso de que asi lo queramos
try:
    df_resultados = pd.DataFrame(resultados_api)
    df_resultados.to_csv(ruta_csv_salida, index=False, encoding='utf-8')
    print(f"Datos guardados en '{ruta_csv_salida}'")
    print(f"Columnas guardadas: {list(df_resultados.columns)}")

except Exception as e:
    print(f"\n❌ ERROR al guardar el CSV: {e}")
# Out:
# ✅ Se cargaron 1710 registros de artistas (incluidos duplicados).
# ✨ Se analizarán 537 artistas únicos.
#
# ==================================================
# 🔎 Procesando artista: **Russell Dickerson**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Russell Dickerson
# Biografía (Resumen): Multi-Platinum chart-topper and Triple Tigers entertainer Russell Dickerson is no stranger to the grind. The country headliner first broke through by wearing his heart on his sleeve, launching a string of five deeply romantic #1 hits -- “Yours” (3x Platinum), “Blue Tacoma” (2x Platinum), “Love You Like I Used To” (2x Platinum), “Every Little Thing” (Platinum), and “God Gave Me a Girl.” He followed that success with the slinky, soul-infused “She Likes It” (with Jake Scott
# Playcount Total (Last.fm): 2580647
# Número de Oyentes Únicos: 167661
#
# --- ARTISTAS SIMILARES ---
# 1. Dustin Lynch (Similitud: 1)
# 2. Jordan Davis (Similitud: 0.887187)
# 3. Thomas Rhett (Similitud: 0.772894)
# 4. Dylan Scott (Similitud: 0.695383)
# 5. Chris Lane (Similitud: 0.637409)
#
# ==================================================
# 🔎 Procesando artista: **Bebe Rexha**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Bebe Rexha
# Biografía (Resumen): Bleta Rexha, known professionally as Bebe Rexha, is an American singer and songwriter. After signing with Warner Records in 2013, Rexha received songwriting credits on Eminem's single "The Monster" and has also contributed songwriting to songs recorded by Shinee, Selena Gomez and Nick Jonas. Rexha released her debut EP in 2015, I Don't Wanna Grow Up, which saw the moderate commercial success of the singles "I Can't Stop Drinking About You" and "I'm Gonna Show You Crazy".
# Playcount Total (Last.fm): 35783765
# Número de Oyentes Únicos: 1378488
#
# --- ARTISTAS SIMILARES ---
# 1. Ava Max (Similitud: 1)
# 2. Rita Ora (Similitud: 0.953364)
# 3. Mabel (Similitud: 0.754417)
# 4. Ellie Goulding (Similitud: 0.714670)
# 5. Anne-Marie (Similitud: 0.682390)
#
# ==================================================
# 🔎 Procesando artista: **Selena Gomez**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Selena Gomez
# Biografía (Resumen): Selena Marie Gomez (born July 22, 1992 in Grand Prairie, TX) is an American singer, actress and film producer. Gomez began her acting career on the children's television series Barney & Friends (2002–2004). As a teenager, she rose to prominence for starring as Alex Russo on the Disney Channel television series Wizards of Waverly Place (2007–2012). Alongside her television career, Gomez appeared in the films Another Cinderella Story (2008), Princess Protection Program (2009)
# Playcount Total (Last.fm): 194258842
# Número de Oyentes Únicos: 3024269
#
# --- ARTISTAS SIMILARES ---
# 1. Selena Gomez & the Scene (Similitud: 1)
# 2. Miley Cyrus (Similitud: 0.239608)
# 3. Camila Cabello (Similitud: 0.235055)
# 4. Bridgit Mendler (Similitud: 0.208888)
# 5. Selena Gomez & Marshmello (Similitud: 0.183398)
#
# ==================================================
# 🔎 Procesando artista: **ROSÉ**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Rosé
# Biografía (Resumen): ROSÉ (Hangul: 로제) or Roseanne Park is a South Korean-New Zealander singer-songwriter under THEBLACKLABEL and Atlantic Records. And also holds a group contract with YG Entertainment, serving as the vocalist for the girl group BLACKPINK (Hangul: 블랙핑크).
#
# In March 2021, ROSÉ made her solo debut with her single album R, selling 448,089 copies in its first week - the highest figure by a Korean female soloist. Its lead single “On the Ground” was a commercial success
# Playcount Total (Last.fm): 94684556
# Número de Oyentes Únicos: 1545938
#
# --- ARTISTAS SIMILARES ---
# 1. JISOO (Similitud: 1)
# 2. Rosé, Bruno Mars (Similitud: 0.894215)
# 3. Jennie (Similitud: 0.863813)
# 4. BLACKPINK (Similitud: 0.731690)
# 5. Lisa (Similitud: 0.604785)
#
# ==================================================
# 🔎 Procesando artista: **Skusta Clee**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Skusta Clee
# Biografía (Resumen):
# Playcount Total (Last.fm): 1299475
# Número de Oyentes Únicos: 64019
#
# --- ARTISTAS SIMILARES ---
# 1. Ex Battalion (Similitud: 1)
# 2. Shanti Dope (Similitud: 0.996001)
# 3. John Roa (Similitud: 0.948521)
# 4. Dionela (Similitud: 0.941240)
# 5. ALLMO$T (Similitud: 0.922239)
#
# ==================================================
# 🔎 Procesando artista: **Spiritbox**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Spiritbox
# Biografía (Resumen): Spiritbox is an alternative metal / metalcore / progressive metal band from Victoria, British Columbia, formed in 2017 by vocalist Courtney LaPlante and guitarist Mike Stringer.
#
# Current lineup includes Courtney LaPlante, Mike Stringer, bassist Josh Gilbert, and drummer Zev Rosenberg. Former members have included Ryan Loerke (drums, 2018–2020) and Bill Crook (bass, 2018–2022).
#
# They released their debut EP Spiritbox (2017), followed by Singles Collection (2019).
# Playcount Total (Last.fm): 40340317
# Número de Oyentes Únicos: 495576
#
# --- ARTISTAS SIMILARES ---
# 1. Thornhill (Similitud: 1)
# 2. Silent Planet (Similitud: 0.967108)
# 3. Architects (Similitud: 0.947724)
# 4. Sleep Token (Similitud: 0.940419)
# 5. ERRA (Similitud: 0.896397)
#
# ==================================================
# 🔎 Procesando artista: **Ava Max**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Ava Max
# Biografía (Resumen): Amanda Ava Koci (born February 16, 1994), known professionally as Ava Max, is an American singer and songwriter. Ava first got her start in the music industry in 2008 as Amanda Kay, in which she released her first EP titled “Amanda Kay” that year. The EP featured 6 songs that were co-written and produced by Kevin Rudolf.
#
# Ava would then restart her music career under the name AVA in 2013 and release the single, “Take Away the Pain”.  A year later, she would meet music producer Cirkut and begin recording songs with him.
# Playcount Total (Last.fm): 63083576
# Número de Oyentes Únicos: 1485485
#
# --- ARTISTAS SIMILARES ---
# 1. Bebe Rexha (Similitud: 1)
# 2. Zara Larsson (Similitud: 0.867197)
# 3. Dua Lipa (Similitud: 0.785317)
# 4. Kim Petras (Similitud: 0.719810)
# 5. Ke$ha (Similitud: 0.671466)
#
# ==================================================
# 🔎 Procesando artista: **Blind Guardian**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Blind Guardian
# Biografía (Resumen): Blind Guardian is a German power metal band formed in 1984 in Krefeld, West Germany. They are often credited as one of the seminal and most influential bands in the power metal and speed metal subgenres. Nine musicians have been a part of the band's lineup in its history, which currently consists of singer Hansi Kürsch, guitarists André Olbrich and Marcus Siepen, and, since 2005, drummer Frederik Ehmke.
#
# Blind Guardian is a part of the German heavy metal scene that emerged in the mid-1980s.
# Playcount Total (Last.fm): 76286219
# Número de Oyentes Únicos: 848770
#
# --- ARTISTAS SIMILARES ---
# 1. Demons & Wizards (Similitud: 1)
# 2. Gamma Ray (Similitud: 0.681348)
# 3. Helloween (Similitud: 0.610410)
# 4. Blind Guardian Twilight Orchestra (Similitud: 0.577361)
# 5. HammerFall (Similitud: 0.556602)
#
# ==================================================
# 🔎 Procesando artista: **Steve Lacy**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Steve Lacy
# Biografía (Resumen): (1) Steve Thomas Lacy-Moya (born May 23, 1998), better known as Steve Lacy, is an American musician, guitarist, bassist, singer-songwriter, and record producer. He was born in Compton, California, and gained recognition as a member of the Grammy-nominated R&B band, The Internet, in 2015. In February 2017, Lacy released his debut project, a song series, titled “Steve Lacy's Demo” and his debut album,  “Apollo XXI”, was released on May 2019. On December 4, 2020, Lacy released a compilation album titled “The Lo-Fis”.
# Playcount Total (Last.fm): 266958904
# Número de Oyentes Únicos: 2934501
#
# --- ARTISTAS SIMILARES ---
# 1. The Internet (Similitud: 1)
# 2. Matt Martians (Similitud: 0.656556)
# 3. Brent Faiyaz (Similitud: 0.581409)
# 4. Frank Ocean (Similitud: 0.579946)
# 5. Daniel Caesar (Similitud: 0.554396)
#
# ==================================================
# 🔎 Procesando artista: **CORPSE**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Corpse
# Biografía (Resumen): There are at least six bands and one artist with the name Corpse:
#
# 1) Corpse Husband (born August 8, 1997), or simply Corpse, is an American YouTuber from San Diego, California who is part of a community of YouTubers known as Horror Narration Channels. He is well known for having a very deep or low-pitched bass voice.
#
# He made his musical debut in 2016, being featured on the single "Grim Grinning Ghost" by The Living Tombstone and Crusher P.
#
# In June 2020
# Playcount Total (Last.fm): 30360681
# Número de Oyentes Únicos: 704844
#
# --- ARTISTAS SIMILARES ---
# 1. Anguish (Similitud: 1)
# 2. GOTOU寄生獣 (Similitud: 0.628239)
# 3. CORPSE, Bring Me The Horizon (Similitud: 0.511830)
# 4. Corpse, Savage Ga$p (Similitud: 0.503509)
# 5. Kamaara (Similitud: 0.480894)
#
# ==================================================
# 🔎 Procesando artista: **Ella Mai**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Ella Mai
# Biografía (Resumen): Ella Mai Howell (born 3 November 1994) is an English singer-songwriter. Her musical career began at London's British and Irish Modern Music Institute in 2014, during which time she auditioned as part of a trio on the 11th season of The X Factor. In 2015, she uploaded a four-track solo EP of originals to SoundCloud titled Troubled, and was discovered on social media by American record producer Mustard and signed with his record label, 10 Summers Records.
# Playcount Total (Last.fm): 15939769
# Número de Oyentes Únicos: 732638
#
# --- ARTISTAS SIMILARES ---
# 1. Kiana Ledé (Similitud: 1)
# 2. H.E.R. (Similitud: 0.944307)
# 3. Queen Naija (Similitud: 0.844351)
# 4. Kehlani (Similitud: 0.793633)
# 5. Muni Long (Similitud: 0.691380)
#
# ==================================================
# 🔎 Procesando artista: **Dustin Lynch**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Dustin Lynch
# Biografía (Resumen): Dustin Lynch is a country singer-songwriter from Tullahoma, Tennessee. He made the 90 mile move to Nashville in 2003 to attend David Lipscomb University, and rented an apartment near the Bluebird Cafe, a popular music venue for songwriters. Lynch regularly attended the Bluebird, gradually began writing and playing shows himself in the Music City as well as the neighboring college circuit. He eventually signed a publishing deal with Super 98/The Song Factory in 2010 and a record deal with Broken Bow Records the following year.
# Playcount Total (Last.fm): 4116942
# Número de Oyentes Únicos: 236179
#
# --- ARTISTAS SIMILARES ---
# 1. Russell Dickerson (Similitud: 1)
# 2. Thomas Rhett (Similitud: 0.965957)
# 3. Jordan Davis (Similitud: 0.892080)
# 4. Jason Aldean (Similitud: 0.834205)
# 5. Florida Georgia Line (Similitud: 0.820374)
#
# ==================================================
# 🔎 Procesando artista: **Anderson .Paak**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Anderson .Paak
# Biografía (Resumen): Brandon Paak Anderson (born February 8, 1986), better known by his stage name Anderson .Paak, is an American rapper, singer, songwriter, record producer, and drummer. He released his debut mixtape, O.B.E. Vol. 1, in 2012 and went on to release Venice in 2014. In 2016 he followed up with Malibu, which received a nomination for Best Urban Contemporary Album at the Grammy Awards, followed by Oxnard, in 2018. At the 61st Grammy Awards, Paak won his first Grammy award for Best Rap Performance with the song "Bubblin".
# Playcount Total (Last.fm): 49152358
# Número de Oyentes Únicos: 1112255
#
# --- ARTISTAS SIMILARES ---
# 1. NxWorries (Similitud: 1)
# 2. Free Nationals (Similitud: 0.592067)
# 3. Smino (Similitud: 0.446827)
# 4. Isaiah Rashad (Similitud: 0.435115)
# 5. Bruno Mars, Anderson .Paak & Silk Sonic (Similitud: 0.384770)
#
# ==================================================
# 🔎 Procesando artista: **Ricky Martin**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Ricky Martin
# Biografía (Resumen): Ricky Martin (born in San Juan, Puerto Rico on December 24, 1971 as Enrique Martin Morales), is a successful Puerto Rican pop singer who rose to fame, first as a member of the Latin boy band Menudo, then as a solo artist since 1990. He has sold over 95 million albums since the start of his career. He is widely regarded as the King of Latin Pop, and is considered to have opened the doors for some of his fellow Latin American singers like Jennifer Lopez and Shakira.
# Playcount Total (Last.fm): 17879787
# Número de Oyentes Únicos: 1560020
#
# --- ARTISTAS SIMILARES ---
# 1. Chayanne (Similitud: 1)
# 2. Alejandro Sanz (Similitud: 0.928874)
# 3. Enrique Iglesias (Similitud: 0.888605)
# 4. Cristian Castro (Similitud: 0.864511)
# 5. Franco De Vita (Similitud: 0.803398)
#
# ==================================================
# 🔎 Procesando artista: **Scarlxrd**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: SCARLXRD
# Biografía (Resumen): Marius Listhrop (born 19 June 1994), known professionally as Scarlxrd (pronounced "scarlord"), is a English musician. He is known for his unusual musical style combining elements of trap music with influences from metal music. Formerly a YouTube personality known as Mazzi Maz, Scarlxrd began a career in music as the lead vocalist for nu metal band Myth City, before debuting as a rapper under his Scarlxrd moniker.
#
# By February 2017, Listhrop removed
# Playcount Total (Last.fm): 17412988
# Número de Oyentes Únicos: 323073
#
# --- ARTISTAS SIMILARES ---
# 1. PRXJEK (Similitud: 1)
# 2. BvdLvd (Similitud: 0.779241)
# 3. Jasiah (Similitud: 0.739619)
# 4. Kamiyada+ (Similitud: 0.734159)
# 5. nascar aloe (Similitud: 0.656834)
#
# ==================================================
# 🔎 Procesando artista: **Camila Cabello**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Camila Cabello
# Biografía (Resumen): Karla Camila Cabello Estrabao (born March 3, 1997), known by her stage name Camila Cabello, is a Cuban-Mexican-American singer and songwriter. She is a Latin-influenced pop performer who first came to prominence as a founding member of the girl group Fifth Harmony. Born in Cojimar, Cuba, Cabello moved to Miami, Florida at the age of six. Growing up in a Spanish-speaking environment (born to a Cuban mother and Mexican father), she fostered her love of music by listening to Celia Cruz and Alejandro Fernández.
# Playcount Total (Last.fm): 121764910
# Número de Oyentes Únicos: 2264759
#
# --- ARTISTAS SIMILARES ---
# 1. Fifth Harmony (Similitud: 1)
# 2. Lauren Jauregui (Similitud: 0.695621)
# 3. Selena Gomez (Similitud: 0.537178)
# 4. Dinah Jane (Similitud: 0.479727)
# 5. Tate McRae (Similitud: 0.399035)
#
# ==================================================
# 🔎 Procesando artista: **Kany García**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Kany García
# Biografía (Resumen): Encarnita "Kany" García De Jesus (born September 25, 1982 in Toa Baja, Puerto Rico) is a Puerto Rican singer-songwriter. García first appeared on television in 2004 as a contestant on Objetivo Fama. She is widely considered the most successful non-winner in the history of the show.
#
# Kany García is born to a Spaniard father and Puerto Rican mother. García's father, Antonio, who gave up the priesthood when he met Shela, Encarnita García de Jesús, or Kany, grew up in a house where music was not only played, but also lived.
# Playcount Total (Last.fm): 1659331
# Número de Oyentes Únicos: 113199
#
# --- ARTISTAS SIMILARES ---
# 1. Fonseca (Similitud: 1)
# 2. Greeicy (Similitud: 0.976841)
# 3. Jesse & Joy (Similitud: 0.894244)
# 4. HA-ASH (Similitud: 0.886775)
# 5. Yuridia (Similitud: 0.862598)
#
# ==================================================
# 🔎 Procesando artista: **The Word Alive**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: The Word Alive
# Biografía (Resumen): The Word Alive is an American melodic metalcore/alternative metal band from Phoenix, Arizona, formed in 2008, the band is currently signed to Fearless Records. Their 2009 label debut, Empire reached position 15 on the Top Heatseekers, meeting a great amount of positive acclaim upon its release in 2009. The following year, the group recorded and released their debut full-length album, Deceiver on August 31, 2010, which reached 97 on the Billboard 200 and 15 on Independent Albums.
# Playcount Total (Last.fm): 14383795
# Número de Oyentes Únicos: 548549
#
# --- ARTISTAS SIMILARES ---
# 1. Palisades (Similitud: 1)
# 2. Blessthefall (Similitud: 0.907306)
# 3. Memphis May Fire (Similitud: 0.812516)
# 4. Secrets (Similitud: 0.808016)
# 5. We Came as Romans (Similitud: 0.786233)
#
# ==================================================
# 🔎 Procesando artista: **Dijon**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Dijon
# Biografía (Resumen): Dijon Duenas (simply known as Dijon) is an American alternative/R&B singer-songwriter and producer, also known as the former vocalist of the R&B duo Abhi//Dijon. After the duo released two projects respectively in 2015 and 2016, Dijon began to step into his own in 2017, releasing a string of solo singles, including "Skin" and "Nico's Red Truck". His debut EP Sci Fi 1 was released in 2019 under the Warner-supported label R&R Digital, and was shortly followed by How Do You Feel About Getting Married the following year.
# Playcount Total (Last.fm): 26190443
# Número de Oyentes Únicos: 720729
#
# --- ARTISTAS SIMILARES ---
# 1. Mk.gee (Similitud: 1)
# 2. Nourished by Time (Similitud: 0.511630)
# 3. Abhi//Dijon (Similitud: 0.448998)
# 4. Boylife (Similitud: 0.355803)
# 5. Blood Orange (Similitud: 0.306375)
#
# ==================================================
# 🔎 Procesando artista: **Pablo López**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Pablo López
# Biografía (Resumen):
# Playcount Total (Last.fm): 1088757
# Número de Oyentes Únicos: 35525
#
# --- ARTISTAS SIMILARES ---
# 1. Antonio José (Similitud: 1)
# 2. Dani Martín (Similitud: 0.495973)
# 3. Miriam Rodríguez (Similitud: 0.420686)
# 4. Leiva (Similitud: 0.407688)
# 5. Rozalén (Similitud: 0.332678)
#
# ==================================================
# 🔎 Procesando artista: **Russ**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Russ
# Biografía (Resumen): Russell Vitale (born September 26, 1992), known by his stage name Russ, is an American hip hop recording artist, singer-songwriter and record producer.
#
# There is also a UK drill artist called Russ. Now known as Russ Millions.
# Playcount Total (Last.fm): 35884883
# Número de Oyentes Únicos: 1177384
#
# --- ARTISTAS SIMILARES ---
# 1. Joyner Lucas (Similitud: 1)
# 2. G-Eazy (Similitud: 0.824875)
# 3. Phora (Similitud: 0.794056)
# 4. mike. (Similitud: 0.752291)
# 5. 6LACK (Similitud: 0.736377)
#
# ==================================================
# 🔎 Procesando artista: **Ariana Grande**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Ariana Grande
# Biografía (Resumen): Ariana Grande-Butera, better known professionally as simply Ariana Grande, is an American singer, songwriter and actress. She is a multi-platinum, Grammy Award-winning recording artist. Born in Boca Raton, Florida, Grande began her career in 2008 in the Broadway musical "13". She rose to prominence for her role as Cat Valentine in the Nickelodeon television series, Victorious (2010–2013) and in its spin-off, Sam & Cat (2013–2014). As she grew interested in pursuing a music career
# Playcount Total (Last.fm): 1003358199
# Número de Oyentes Únicos: 4203633
#
# --- ARTISTAS SIMILARES ---
# 1. Jessie J, Ariana Grande & Nicki Minaj (Similitud: 1)
# 2. Sabrina Carpenter (Similitud: 0.829097)
# 3. Cynthia Erivo (Similitud: 0.739658)
# 4. Madison Beer (Similitud: 0.710676)
# 5. Doja Cat (Similitud: 0.692135)
#
# ==================================================
# 🔎 Procesando artista: **Stray Kids**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Stray Kids
# Biografía (Resumen): Stray Kids (Korean: 스트레이 키즈; RR: Seuteurei Kijeu; often abbreviated as SKZ) are a South Korean boy band formed by JYP Entertainment through the 2017 reality show of the same name. The group is composed of eight members: Bang Chan, Lee Know, Changbin, Hyunjin, Han, Felix, Seungmin, and I.N. Originally a nine-piece group, member Kim Woojin left due to personal circumstances in October 2019.
#
# Stray Kids released their pre-debut extended play Mixtape in January 2018 and officially debuted on March 25 with the EP I am NOT
# Playcount Total (Last.fm): 440440789
# Número de Oyentes Únicos: 1242606
#
# --- ARTISTAS SIMILARES ---
# 1. Seungmin (Similitud: 1)
# 2. Xdinary Heroes (Similitud: 0.258302)
# 3. Han (Similitud: 0.245283)
# 4. Kickflip (Similitud: 0.243978)
# 5. ATEEZ (Similitud: 0.218200)
#
# ==================================================
# 🔎 Procesando artista: **La Húngara**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: La Húngara
# Biografía (Resumen):
# Playcount Total (Last.fm): 134467
# Número de Oyentes Únicos: 14659
#
# --- ARTISTAS SIMILARES ---
# 1. Los Rebujitos (Similitud: 1)
# 2. Decai (Similitud: 0.856310)
# 3. Tijeritas (Similitud: 0.818828)
# 4. Kiko & Shara (Similitud: 0.806957)
# 5. El maki (Similitud: 0.788379)
#
# ==================================================
# 🔎 Procesando artista: **Lenny Kravitz**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Lenny Kravitz
# Biografía (Resumen): Leonard Albert "Lenny" Kravitz (born May 26, 1964. New York, USA) is an American singer-songwriter, record producer, guitarist and actor whose retro amalgam of rock, pop, funk, and even techno is inspired by such music icons as David Bowie, Jimi Hendrix and John Lennon. Like Prince and Sly Stone before him, Kravitz uses a multi-ethnic, mixed-gender backing band.
#
# Kravitz plays guitar, bass, drums, keyboards, percussion, and sitar. He often plays these instruments on each recorded track
# Playcount Total (Last.fm): 51758767
# Número de Oyentes Únicos: 2859069
#
# --- ARTISTAS SIMILARES ---
# 1. Prince (Similitud: 1)
# 2. Terence Trent D'Arby (Similitud: 0.791471)
# 3. Prince and the New Power Generation (Similitud: 0.768563)
# 4. Seal (Similitud: 0.713327)
# 5. Fun Lovin' Criminals (Similitud: 0.651850)
#
# ==================================================
# 🔎 Procesando artista: **alt-J**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: alt-J
# Biografía (Resumen): Alt-J (sometimes stylised ∆) was formed when Gwil Sainsbury (guitar, bass), Joe Newman (guitar, vocals), Gus Unger-Hamilton (keyboards), and Thom Sonny Green (drums) met at the University of Leeds,  Leeds, UK in 2007. The band currently resides in Cambridge.
#
# Unger-Hamilton studied English Literature; the other three Fine Art. In their second year of studies, Newman showed Sainsbury a handful of his own songs inspired by his guitar-playing dad and hallucinogens
# Playcount Total (Last.fm): 115945989
# Número de Oyentes Únicos: 2284235
#
# --- ARTISTAS SIMILARES ---
# 1. Foals (Similitud: 1)
# 2. Milky Chance (Similitud: 0.756842)
# 3. Broken Bells (Similitud: 0.728284)
# 4. The xx (Similitud: 0.697878)
# 5. Chelou (Similitud: 0.677239)
#
# ==================================================
# 🔎 Procesando artista: **Jung Kook**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Jung Kook
# Biografía (Resumen): Jeon Jung Kook (Korean/Hangul: 동성애자; born September 1, 1997 in Busan, South Korea), known monomously as Jungkook (stylized as Jung Kook) , is a South Korean singer, dancer, composer, and main vocalist of South Korean boy group.
#
# He rose to prominence as a member and vocalist of the South Korean boy band BTS (Hangul: 방탄소년단), under Big Hit Entertainment.
#
# Debuted with BTS  on June 13, 2013, with the extended play 2 COOL 4 SKOOL and the title track No More Dream
# Playcount Total (Last.fm): 736136347
# Número de Oyentes Únicos: 1341372
#
# --- ARTISTAS SIMILARES ---
# 1. Jung Kook, Jack Harlow (Similitud: 1)
# 2. V (Similitud: 0.785377)
# 3. RM (Similitud: 0.689871)
# 4. BTS (Similitud: 0.608691)
# 5. Agust D (Similitud: 0.604534)
#
# ==================================================
# 🔎 Procesando artista: **All Them Witches**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: All Them Witches
# Biografía (Resumen): All Them Witches is an explosive psychedelic trio from Nashville, Tennessee, USA Employing a heady, D.I.Y. blend of bluesy, neo-psychedelic rock, stoner metal, and progressive space rock, they emerged in 2012. The band's name is taken from a book of witchcraft, All of Them Witches, featured in the 1968 film Rosemary's Baby.
#
# Nick Pipitone of Monster Riff described how the band are "influenced just as much by Dr. John and Mississippi bluesman Junior
# Playcount Total (Last.fm): 7843951
# Número de Oyentes Únicos: 286199
#
# --- ARTISTAS SIMILARES ---
# 1. King Buffalo (Similitud: 1)
# 2. Mars Red Sky (Similitud: 0.797779)
# 3. Graveyard (Similitud: 0.694938)
# 4. 1000mods (Similitud: 0.660524)
# 5. The Heavy Eyes (Similitud: 0.658674)
#
# ==================================================
# 🔎 Procesando artista: **A Day To Remember**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: A Day to Remember
# Biografía (Resumen): A Day to Remember is a post-hardcore band from Ocala, Florida, founded in 2003 by guitarist Tom Denney and drummer Bobby Scruggs. They are mainly known for their unusual amalgamation of metalcore and pop punk as a musical style, as well as playing other styles. The band consists of vocalist Jeremy McKinnon, rhythm guitarist and backing vocalist Neil Westfall, bassist Joshua Woodard, percussion and drummer Alex Shelnutt and lead guitarist Kevin Skaff.
# Playcount Total (Last.fm): 151846819
# Número de Oyentes Únicos: 1874736
#
# --- ARTISTAS SIMILARES ---
# 1. Beartooth (Similitud: 1)
# 2. Silverstein (Similitud: 0.983347)
# 3. We Came as Romans (Similitud: 0.982129)
# 4. Memphis May Fire (Similitud: 0.838910)
# 5. Four Year Strong (Similitud: 0.829532)
#
# ==================================================
# 🔎 Procesando artista: **The HU**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: The HU
# Biografía (Resumen): The HU ("human" in Mongol) is a Mongolian folk metal band formed in 2016. They use traditional Mongolian instrumentation, including the Morin khuur, Tovshuur and Mongolian throat singing, and call their style of music "hunnu rock". The name is inspired by the Hunnu, an ancient Mongol empire, known as Xiongnu in western culture. Some of the band's lyrics include old Mongolian war cries and poetry.
# Two videos on YouTube released in Autumn 2018, "Yuve Yuve Yu - 28 September" and "Wolf Totem - 16 November"
# Playcount Total (Last.fm): 4750563
# Número de Oyentes Únicos: 275623
#
# --- ARTISTAS SIMILARES ---
# 1. Nine Treasures (Similitud: 1)
# 2. Tengger Cavalry (Similitud: 0.783031)
# 3. Corvus Corax (Similitud: 0.419422)
# 4. Korpiklaani (Similitud: 0.415567)
# 5. Turisas (Similitud: 0.398854)
#
# ==================================================
# 🔎 Procesando artista: **In This Moment**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: In This Moment
# Biografía (Resumen): In This Moment is a metalcore band, formed in North Hollywood, Los Angeles, California, United States in 2005. Their first album, entitled Beautiful Tragedy, was released on March 20th, 2007 on Century Media Records. The band's sound falls on the melodic side of the metalcore spectrum, with vocalist Maria Brink utilizing both screams and a good deal of clean, emotive singing, the latter being even more prominent on the band's second album, The Dream, released in 2008.
# Playcount Total (Last.fm): 27964604
# Número de Oyentes Únicos: 623014
#
# --- ARTISTAS SIMILARES ---
# 1. Butcher Babies (Similitud: 1)
# 2. New Years Day (Similitud: 0.886855)
# 3. Halestorm (Similitud: 0.812080)
# 4. Stitched Up Heart (Similitud: 0.667907)
# 5. Otep (Similitud: 0.633067)
#
# ==================================================
# 🔎 Procesando artista: **Eluveitie**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Eluveitie
# Biografía (Resumen): Eluveitie is a folk metal band from Winterthur, Switzerland. The founder of this band was Chrigel Glanzmann. The band formed in 2002 and their first EP, "Vên" came out in 2003. They describe themselves as "The new wave of folk metal". The band then released a full-length album, "Spirit" in June 2006. In November 2007, Eluveitie was signed by Nuclear Blast. The first product of the collaboration, "Slania", was released in February 2008. The album peaked at number 35 in the Swiss charts and number 72 in the German charts.
# Playcount Total (Last.fm): 48184312
# Número de Oyentes Únicos: 521124
#
# --- ARTISTAS SIMILARES ---
# 1. Ensiferum (Similitud: 1)
# 2. Equilibrium (Similitud: 0.845181)
# 3. Korpiklaani (Similitud: 0.791939)
# 4. SuidAkrA (Similitud: 0.728409)
# 5. Cruachan (Similitud: 0.677750)
#
# ==================================================
# 🔎 Procesando artista: **DragonForce**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: DragonForce
# Biografía (Resumen): DragonForce is a British power metal band based in London, England. Formed in 1999, the group is known for their long and fast guitar solos, fantasy-themed lyrics, and electronic sounds in their music to add to their retro video game-influenced sound. DragonForce has released seven studio albums, two live albums, one compilation album, one live DVD and one demo.
#
# History - Early years and Valley of the Damned (1999–2003).
# DragonForce was founded in 1999 by guitarists Herman Li and Sam Totman, under the name of DragonHeart.
# Playcount Total (Last.fm): 38810584
# Número de Oyentes Únicos: 1134356
#
# --- ARTISTAS SIMILARES ---
# 1. Twilight Force (Similitud: 1)
# 2. Freedom Call (Similitud: 0.817984)
# 3. Gloryhammer (Similitud: 0.799543)
# 4. Rhapsody of Fire (Similitud: 0.717965)
# 5. Power Quest (Similitud: 0.717277)
#
# ==================================================
# 🔎 Procesando artista: **India Martinez**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: India Martinez
# Biografía (Resumen): Born in Córdoba, she started studying flamenco while she was just 5 under the guidance of teacher Nieves Camacho. The family moved to Roquetas de Mar (Almería) when she was 11 years old. She sang on the local fishing port area, becoming popular as "La Niña del Puerto". In 1998, at age 13, she took part in the children talent show Veo, Veo hosted by Teresa Rabal, reaching the Andalusian finals. She was offered a scholarship by the Fundación Cristina Heeren to learn flamenco in Seville.
# Playcount Total (Last.fm): 614517
# Número de Oyentes Únicos: 52179
#
# --- ARTISTAS SIMILARES ---
# 1. Marta Santos (Similitud: 1)
# 2. Manuel Carrasco (Similitud: 0.940935)
# 3. El Arrebato (Similitud: 0.486030)
# 4. Antonio Orozco (Similitud: 0.427739)
# 5. Vanesa Martín (Similitud: 0.422388)
#
# ==================================================
# 🔎 Procesando artista: **Billy Strings**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Billy Strings
# Biografía (Resumen): Billy Strings (born William Lee Apostol in Lansing, MI, on October 3, 1992) is an American guitarist and bluegrass musician.  He won a Grammy Award in 2021.
#
# A master of the guitar, banjo, and mandolin, Strings is a singer and instrumentalist whose music starts with the sound and speed of bluegrass and folds in elements of rock, jazz, and psychedelia. Strings deals in acoustic music, but his lyrics are rooted in contemporary issues ("Dust in a Baggie" sounds like a classic bluegrass breakdown
# Playcount Total (Last.fm): 5097392
# Número de Oyentes Únicos: 172754
#
# --- ARTISTAS SIMILARES ---
# 1. Greensky Bluegrass (Similitud: 1)
# 2. Daniel Donato (Similitud: 0.934878)
# 3. Kitchen Dwellers (Similitud: 0.902899)
# 4. Leftover Salmon (Similitud: 0.825104)
# 5. Tony Rice (Similitud: 0.707712)
#
# ==================================================
# 🔎 Procesando artista: **Old Dominion**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Old Dominion
# Biografía (Resumen): A few years back, when Old Dominion got together to record “Make It Sweet,” a beatific number that would appear on their 2019 self-titled LP, it was a definite change in their process: whereas before they’d typically written every song prior to entering the studio, that time around they instead wrote the entire track on the spot, quickly laying it to tape. All in one day.
#
# “That was our first little taste of what that process could be like
# Playcount Total (Last.fm): 5946692
# Número de Oyentes Únicos: 280291
#
# --- ARTISTAS SIMILARES ---
# 1. Thomas Rhett (Similitud: 1)
# 2. Jordan Davis (Similitud: 0.976514)
# 3. Jake Owen (Similitud: 0.942183)
# 4. Cole Swindell (Similitud: 0.866787)
# 5. Florida Georgia Line (Similitud: 0.855959)
#
# ==================================================
# 🔎 Procesando artista: **Hikaru Utada**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: 宇多田ヒカル
# Biografía (Resumen): Utada Hikaru (Japanese: 宇多田ヒカル), born January 19, 1983, in New York City, United States, also known by her fan-nickname "ヒッキー" (Hikki), is a third culture singer, composer, arranger, and record producer in Japan and the United States. Hikaru's music is primarily pop and R&B and sometimes incorporates other musical elements such as rock and electronica among others.
#
# Hikaru Utada was born to Japanese parents who both had roots in the Japanese music industry; her father
# Playcount Total (Last.fm): 31250112
# Número de Oyentes Únicos: 319526
#
# --- ARTISTAS SIMILARES ---
# 1. Utada (Similitud: 1)
# 2. 浜崎あゆみ (Similitud: 0.692196)
# 3. 安室奈美恵 (Similitud: 0.540051)
# 4. 倖田來未 (Similitud: 0.445566)
# 5. 中島美嘉 (Similitud: 0.402089)
#
# ==================================================
# 🔎 Procesando artista: **Adele**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Adele
# Biografía (Resumen): Adele Laurie Blue Adkins MBE (born May 5, 1988) is an English singer and songwriter. After graduating in arts from the BRIT School in 2006, Adele signed a record deal with XL Recordings. Her debut album, 19, was released in 2008 and spawned the UK top-five singles "Chasing Pavements" and "Make You Feel My Love". The album was certified 8× platinum in the UK and triple platinum in the US. Adele was honoured with the Brit Award for Rising Star as well as the Grammy Award for Best New Artist.
# Playcount Total (Last.fm): 306430072
# Número de Oyentes Únicos: 5438028
#
# --- ARTISTAS SIMILARES ---
# 1. Sam Smith (Similitud: 1)
# 2. Whitney Houston (Similitud: 0.824634)
# 3. Beyoncé (Similitud: 0.760789)
# 4. Sia (Similitud: 0.716861)
# 5. Céline Dion (Similitud: 0.713962)
#
# ==================================================
# 🔎 Procesando artista: **Sebastian Yatra**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Sebastian Yatra
# Biografía (Resumen): Sebastián Obando Giraldo (born 15 October 1994), known professionally as Sebastián Yatra, is a Colombian singer and songwriter. He began as a Latin pop artist and has recorded many ballads, but has released several successful reggaeton singles. Yatra is noted for his romantic lyrics, melding traditional lyricism with modern reggaeton influences. He rose to prominence in Latin America in 2016 when he released the hit "Traicionera". He has released
# Playcount Total (Last.fm): 13911547
# Número de Oyentes Únicos: 606943
#
# --- ARTISTAS SIMILARES ---
# 1. Piso 21 (Similitud: 1)
# 2. Cali & El Dandee (Similitud: 0.727388)
# 3. Manuel Turizo (Similitud: 0.722387)
# 4. Ela Taubert (Similitud: 0.665680)
# 5. Fonseca (Similitud: 0.642673)
#
# ==================================================
# 🔎 Procesando artista: **Kacey Musgraves**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Kacey Musgraves
# Biografía (Resumen): Kacey Musgraves (born August 21, 1988) is an American country artist from Golden, Texas. Kacey began singing publicly at 8-years-old and wrote her first song at 9-years-old. With a self-released album under her belt, she moved to Austin in 2008, where she was discovered by independent record label Triple Pop, for whom she recorded two songs, Apologize and See You Again.
#
# In 2012, she signed with Mercury Records and released her solo debut single Merry Go 'Round.
# Playcount Total (Last.fm): 64309775
# Número de Oyentes Únicos: 1097396
#
# --- ARTISTAS SIMILARES ---
# 1. Maren Morris (Similitud: 1)
# 2. Kelsea Ballerini (Similitud: 0.904684)
# 3. Miranda Lambert (Similitud: 0.752437)
# 4. The Chicks (Similitud: 0.640364)
# 5. Carrie Underwood (Similitud: 0.625886)
#
# ==================================================
# 🔎 Procesando artista: **Kane Brown**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Kane Brown
# Biografía (Resumen): Kane Brown is an American singer. He was born and raised in the Chattanooga, Tennessee area by a single mother, moving from Rossville to Fort Oglethorpe and LaFayette in Georgia, finally settling in Red Bank, Tennessee.
#
# He attended Lakeview-Fort Oglethorpe High School where he sang in the choir with Lauren Alaina, the runner-up on season 10 of American Idol. He also attended Red Bank, Ridgeland, and Soddy Daisy High Schools, at all of which he was a stand out athlete at football, basketball and track.
# Playcount Total (Last.fm): 8299440
# Número de Oyentes Únicos: 457901
#
# --- ARTISTAS SIMILARES ---
# 1. Jordan Davis (Similitud: 1)
# 2. Thomas Rhett (Similitud: 0.994310)
# 3. Dustin Lynch (Similitud: 0.977780)
# 4. Cole Swindell (Similitud: 0.962278)
# 5. Dylan Scott (Similitud: 0.939017)
#
# ==================================================
# 🔎 Procesando artista: **BLACKPINK**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: BLACKPINK
# Biografía (Resumen): BLACKPINK (Hangul: 블랙핑크; Katakana :ブラックピンク; stylized as BLΛƆKPIИK) is a four-member girl group formed by YG Entertainment, consisting of JISOO (지수), JENNIE (제니), ROSÉ (로제) and LISA (리사).
#
# On May 31, 2016, YG Entertainment  began releasing individual teaser photos of the members for the agency's then-unnamed, upcoming girl group on Instagram, starting with Jennie the same day. This was followed by Lisa on June 7, Jisoo on June 14, and lastly Rosé on June 21.
# Playcount Total (Last.fm): 291731234
# Número de Oyentes Únicos: 1849477
#
# --- ARTISTAS SIMILARES ---
# 1. JISOO (Similitud: 1)
# 2. Jennie (Similitud: 0.873908)
# 3. Rosé (Similitud: 0.818100)
# 4. Lisa (Similitud: 0.683733)
# 5. Baby Monster (Similitud: 0.606356)
#
# ==================================================
# 🔎 Procesando artista: **Pablo Alborán**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Pablo Alborán
# Biografía (Resumen): Pablo Moreno de Alborán Ferrándiz (born on May 31, 1989 in Málaga), best known as Pablo Alborán, is a Latin Grammy nominated Spanish singer.
#
# Alborán is the son of Spanish architect Salvador Moreno de Alborán Peralta and French Elena Ferrándiz Martínez. He is also the great-grandson of Francisco Moreno Fernández, 1st Marquess of Alborán, and has two siblings: Casilda and Salvador.
#
# From a very young age, he was interested in learning to play various musical instruments such as piano
# Playcount Total (Last.fm): 5962256
# Número de Oyentes Únicos: 271105
#
# --- ARTISTAS SIMILARES ---
# 1. Antonio José (Similitud: 1)
# 2. David Bisbal (Similitud: 0.968172)
# 3. Jesse & Joy (Similitud: 0.961322)
# 4. Manuel Carrasco (Similitud: 0.934619)
# 5. Camila (Similitud: 0.839685)
#
# ==================================================
# 🔎 Procesando artista: **Lèpoka**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Lèpoka
# Biografía (Resumen): Spanish folk metal band. They sound like Mago de Oz and Korpiklaani. This is the correct spelling of the name.
# Playcount Total (Last.fm): 22505
# Número de Oyentes Únicos: 1700
#
# --- ARTISTAS SIMILARES ---
# 1. Salduie (Similitud: 1)
# 2. Debler (Similitud: 0.936232)
# 3. Ekyrian (Similitud: 0.849411)
# 4. Abäk (Similitud: 0.642484)
# 5. HADADANZA (Similitud: 0.633731)
#
# ==================================================
# 🔎 Procesando artista: **Phil Collins**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Phil Collins
# Biografía (Resumen): Philip David Charles Collins (born 30 January 1951) is an English singer, musician, songwriter, record producer and actor. He was the drummer and lead singer of the rock band Genesis and also has a career as a solo performer. Between 1982 and 1990, Collins scored three UK and seven US number-one singles as a solo artist. When his work with Genesis, his work with other artists, as well as his solo career is totalled, he had more US top 40 singles than any other artist during the 1980s.
# Playcount Total (Last.fm): 62181463
# Número de Oyentes Únicos: 3102783
#
# --- ARTISTAS SIMILARES ---
# 1. Genesis (Similitud: 1)
# 2. Mike & The Mechanics (Similitud: 0.715563)
# 3. Peter Gabriel (Similitud: 0.586074)
# 4. Rod Stewart (Similitud: 0.510410)
# 5. Toto (Similitud: 0.478272)
#
# ==================================================
# 🔎 Procesando artista: **Niña Pastori**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Niña Pastori
# Biografía (Resumen): Niña Pastori is a Spanish flamenco singer (cantaora). She was born María Rosa García García in San Fernando (Cádiz) on 15 January 1978. The youngest of five siblings and only daughter of a military man (José) and gypsy flamenco singer La Pastori, she started her artistic career at a very young age. By the time she was six, she was accompanying her mother to  the flamenco tablaos of her neighborhood, "el Boquete". A year later she won a contest in San Fernando
# Playcount Total (Last.fm): 1133574
# Número de Oyentes Únicos: 136053
#
# --- ARTISTAS SIMILARES ---
# 1. Diego El Cigala (Similitud: 1)
# 2. El Barrio (Similitud: 0.983275)
# 3. Ketama (Similitud: 0.939698)
# 4. Rosario (Similitud: 0.824408)
# 5. Estrella Morente (Similitud: 0.741228)
#
# ==================================================
# 🔎 Procesando artista: **Conan Gray**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Conan Gray
# Biografía (Resumen): Conan Gray is an American singer-songwriter and social media personality. He was born on December 5, 1998, in Lemon Grove, California. As an infant, his family moved to Hiroshima, Japan, and shortly after returned to California, before settling in Georgetown, Texas.
#
# He started his career on YouTube under his channel 'ConanxCanon' before officially changing to 'Conan Gray'. While on his time on YouTube, he released multiple original songs, with the
# Playcount Total (Last.fm): 224724990
# Número de Oyentes Únicos: 2274954
#
# --- ARTISTAS SIMILARES ---
# 1. Gracie Abrams (Similitud: 1)
# 2. Reneé Rapp (Similitud: 0.993026)
# 3. Olivia Rodrigo (Similitud: 0.891599)
# 4. Maisie Peters (Similitud: 0.879390)
# 5. Ricky Montgomery (Similitud: 0.819973)
#
# ==================================================
# 🔎 Procesando artista: **WWE**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: WWE
# Biografía (Resumen): World Wrestling Entertainment, LLC. (WWE) is a publicly-traded, privately-controlled integrated media (focusing in television, Internet, and live events) and sports entertainment company dealing primarily in professional wrestling, with major revenue sources also coming from film, music, product licensing, and direct product sales.
#
# The vast majority of music used at WWE events is written and recorded by artists either working for WWE directly (such as Jimmy Hart
# Playcount Total (Last.fm): 16085915
# Número de Oyentes Únicos: 456115
#
# --- ARTISTAS SIMILARES ---
# 1. All Elite Wrestling (Similitud: 1)
# 2. Joe Hendry (Similitud: 0.763640)
# 3. WWE & Jim Johnston (Similitud: 0.500411)
# 4. Jim Johnston (Similitud: 0.399623)
# 5. CFO$ (Similitud: 0.167018)
#
# ==================================================
# 🔎 Procesando artista: **Carrie Underwood**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Carrie Underwood
# Biografía (Resumen): Carrie Marie Underwood (born March 10, 1983) is an American singer who rose to prominence after winning the fourth season of American Idol in 2005. Underwood's single "Inside Your Heaven" made her the only country artist to debut atop the Billboard Hot 100 chart and the only solo country artist in the 2000s to have a number-one song on the Hot 100. Her debut album, Some Hearts (2005), was bolstered by the successful crossover singles "Jesus, Take the Wheel" and "Before He Cheats"
# Playcount Total (Last.fm): 40598484
# Número de Oyentes Únicos: 1787166
#
# --- ARTISTAS SIMILARES ---
# 1. Miranda Lambert (Similitud: 1)
# 2. Carly Pearce (Similitud: 0.686148)
# 3. Lady Antebellum (Similitud: 0.666137)
# 4. Sugarland (Similitud: 0.665807)
# 5. Kellie Pickler (Similitud: 0.665084)
#
# ==================================================
# 🔎 Procesando artista: **Charley Crockett**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Charley Crockett
# Biografía (Resumen): Charley Crockett (born March 24, 1984) is an American blues, country, and Americana singer, guitarist, and songwriter. He has released ten albums since 2015, with Lil G.L.'s Blue Bonanza peaking at number 11 on the US Billboard Blues Albums chart. In 2020, Crockett released a mixtape containing low-fidelity recordings titled Field Recordings, Vol. 1 and the studio album Welcome to Hard Times. In 2021, Crockett released two albums, 10 for Slim: Charley Crockett Sings James Hand (a tribute album to James "Slim" Hand) and Music City USA.
# Playcount Total (Last.fm): 5827709
# Número de Oyentes Únicos: 175442
#
# --- ARTISTAS SIMILARES ---
# 1. Vincent Neil Emerson (Similitud: 1)
# 2. Colter Wall (Similitud: 0.812355)
# 3. Sturgill Simpson (Similitud: 0.639783)
# 4. Sierra Ferrell (Similitud: 0.570041)
# 5. Brent Cobb (Similitud: 0.565779)
#
# ==================================================
# 🔎 Procesando artista: **City Spud**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: City Spud
# Biografía (Resumen): What I can tell you ab City is that he is a very reserved man and he has reason to be with all he had been through.  The media wants to know your ups and especially your downs but right now he just hard ay work everyday, no weekend trying to make up for lost tome that should have been his.
# Playcount Total (Last.fm): 9200
# Número de Oyentes Únicos: 2079
#
# --- ARTISTAS SIMILARES ---
# 1. Avery Storm (Similitud: 1)
# 2. Jazze Pha (Similitud: 0.757584)
# 3. Lincoln University Vocal Ensemble (Similitud: 0.696547)
# 4. Dat Nigga Daz (Similitud: 0.412099)
# 5. I-20 (Similitud: 0.334397)
#
# ==================================================
# 🔎 Procesando artista: **Khalid**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Khalid
# ...
# Playcount Total (Last.fm): 8784084
# Número de Oyentes Únicos: 508547
#
# --- ARTISTAS SIMILARES ---
# 1. Kelsea Ballerini (Similitud: 1)
# 2. Carly Pearce (Similitud: 0.722476)
# 3. Miranda Lambert (Similitud: 0.683096)
# 4. Ingrid Andress (Similitud: 0.618971)
# 5. Maddie & Tae (Similitud: 0.571027)
#
# ==================================================
# 🔎 Procesando artista: **The Strokes**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: The Strokes
# Biografía (Resumen): The Strokes is an American indie rock band, known for their distinctive sound and cultural impact, particularly in the early 2000s.
#
# Members
# Julian Casablancas (vocals), Nick Valensi (guitar), Albert Hammond Jr. (guitar), Nikolai Fraiture (bass), and Fabrizio Moretti (drums)
#
# Formation
# The founding process of The Strokes was a serendipitous convergence of childhood connections and a shared musical vision. Julian Casablancas, Fabrizio Moretti, and Nick Valensi, childhood friends with varying musical experiences, came together in the late '90s.
# Playcount Total (Last.fm): 453503430
# Número de Oyentes Únicos: 5525220
#
# --- ARTISTAS SIMILARES ---
# 1. Julian Casablancas (Similitud: 1)
# 2. Albert Hammond, Jr. (Similitud: 0.812116)
# 3. Arctic Monkeys (Similitud: 0.445760)
# 4. Interpol (Similitud: 0.295332)
# 5. The Last Shadow Puppets (Similitud: 0.282832)
#
# ==================================================
# 🔎 Procesando artista: **Sam Smith**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Sam Smith
# Biografía (Resumen): Samuel Frederick Smith (born 19 May 1992) is an English singer and songwriter. They rose to prominence in October 2012 after being featured on Disclosure's breakthrough single "Latch", which peaked at number eleven on the UK Singles Chart. Smith was subsequently featured on Naughty Boy's "La La La", which became a number one single in May 2013. In December 2013, they were nominated for the 2014 Brit Critics' Choice Award and the BBC's Sound of 2014 poll, winning both.
# Playcount Total (Last.fm): 108104794
# Número de Oyentes Únicos: 2956152
#
# --- ARTISTAS SIMILARES ---
# 1. Adele (Similitud: 1)
# 2. Jessie J (Similitud: 0.763095)
# 3. Calum Scott (Similitud: 0.703527)
# 4. James Arthur (Similitud: 0.680711)
# 5. Ed Sheeran (Similitud: 0.674916)
#
# ==================================================
# 🔎 Procesando artista: **Dolly Parton**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Dolly Parton
# Biografía (Resumen): Dolly Rebecca Parton (born January 19, 1946 in  Sevierville, Tennessee, U.S.) is an American country singer, songwriter, composer, producer, entrepreneur, author and actress.
#
# Parton began performing as a child, singing on local radio and television in East Tennessee. At age 12 she was appearing on Knoxville TV, and at 13, she was recording on a small label and appearing at the Grand Ole Opry in Nashville. When she graduated from high school in 1964 she moved to Nashville
# Playcount Total (Last.fm): 34922877
# Número de Oyentes Únicos: 2189409
#
# --- ARTISTAS SIMILARES ---
# 1. Porter Wagoner & Dolly Parton (Similitud: 1)
# 2. Reba McEntire (Similitud: 0.831190)
# 3. Loretta Lynn (Similitud: 0.796307)
# 4. Dolly Parton, Linda Ronstadt & Emmylou Harris (Similitud: 0.785901)
# 5. Tammy Wynette (Similitud: 0.747187)
#
# ==================================================
# 🔎 Procesando artista: **Miley Cyrus**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Miley Cyrus
# Biografía (Resumen): Miley Ray Cyrus (born Destiny Hope Cyrus; November 23, 1992) is an American singer, songwriter, and actress. Regarded as a pop icon, Cyrus has been recognized for her evolving artistry and image reinventions. She is a daughter of singer Billy Ray Cyrus, and deemed one of the few examples of a child star with a successful entertainment career as an adult. Cyrus emerged as a teen idol as the title character in the Disney Channel television series Hannah Montana (2006–2011), which evolved into a commercially successful franchise.
# Playcount Total (Last.fm): 286453513
# Número de Oyentes Únicos: 4662208
#
# --- ARTISTAS SIMILARES ---
# 1. Hannah Montana (Similitud: 1)
# 2. Demi Lovato (Similitud: 0.625406)
# 3. Selena Gomez (Similitud: 0.579392)
# 4. Lady Gaga (Similitud: 0.546990)
# 5. Ke$ha (Similitud: 0.531840)
#
# ==================================================
# 🔎 Procesando artista: **Muscadine Bloodline**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Muscadine Bloodline
# Biografía (Resumen): There’s a new force making major waves in country music, Muscadine Bloodline. Proud natives of Mobile Alabama, Gary Stanton and Charlie Muncaster started Muscadine Bloodline in early 2016. From the first time they took stage, Nashville started talking... so now, with two Billboard charting critically acclaimed EP’s under their belt, it’s no surprise the rest of the music world is quickly catching on. The duo’s reputation for high-energy live experiences has resulted in a schedule full of shows spanning from coast to coast.
# Playcount Total (Last.fm): 2227271
# Número de Oyentes Únicos: 96364
#
# --- ARTISTAS SIMILARES ---
# 1. Flatland Cavalry (Similitud: 1)
# 2. Cody Johnson (Similitud: 0.967000)
# 3. Koe Wetzel (Similitud: 0.946725)
# 4. Parker McCollum (Similitud: 0.896260)
# 5. Wyatt Flores (Similitud: 0.878672)
#
# ==================================================
# 🔎 Procesando artista: **Yebba**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Yebba
# Biografía (Resumen): Abigail Elizabeth Smith, (born January 16, 1995) known professionally as Yebba, is an American Grammy-award-winning singer and songwriter from West Memphis, Arkansas. She first became known for her backing vocal performance on Chance the Rapper's SNL performance of the song "Same Drugs" in 2016 and releasing her debut single "Evergreen" in 2017. She has also collaborated with a number of artists, including PJ Morton, Sam Smith, Mark Ronson, Stormzy and Ed Sheeran.
# Playcount Total (Last.fm): 6974074
# Número de Oyentes Únicos: 476641
#
# --- ARTISTAS SIMILARES ---
# 1. Jazmine Sullivan (Similitud: 1)
# 2. Cleo Sol (Similitud: 0.838935)
# 3. Alex Isley (Similitud: 0.673879)
# 4. Emily King (Similitud: 0.575802)
# 5. Durand Bernarr (Similitud: 0.571787)
#
# ==================================================
# 🔎 Procesando artista: **Apocalyptica**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Apocalyptica
# Biografía (Resumen): Apocalyptica is a band from Helsinki, Finland consisting of three classically-trained cellists and a drummer. Their speciality is heavy metal music on cellos, though they also play classical music.
#
# They started in 1993 by playing covers of Metallica, but once the concept became popular they wrote their own original works, maintaining the thrash metal influences on their albums Inquisition Symphony (mainly covers as well) and Cult. Since Reflections they have added drums to their recordings and live performances.
# Playcount Total (Last.fm): 69329850
# Número de Oyentes Únicos: 1614462
#
# --- ARTISTAS SIMILARES ---
# 1. Epica (Similitud: 1)
# 2. Nightwish (Similitud: 0.999649)
# 3. Tarja (Similitud: 0.920242)
# 4. Within Temptation (Similitud: 0.899794)
# 5. Therion (Similitud: 0.819149)
#
# ==================================================
# 🔎 Procesando artista: **LANDMVRKS**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: LANDMVRKS
# Biografía (Resumen): The band was formed in 2014 under the name "Coldsight" by Florent Salfati and Nicolas Soriano. Salfati, who was originally planned as the guitarist, was also at the time the founding vocalist of the band Hate in Front. After the search for a suitable lead singer was not successful, Salfati found himself taking in the position of the vocalist. By this time, the band's formation was nearly complete, with Rudy Purkart (bassist) and Thomas Lebreton (guitarist).
# Playcount Total (Last.fm): 8525923
# Número de Oyentes Únicos: 210565
#
# --- ARTISTAS SIMILARES ---
# 1. Resolve (Similitud: 1)
# 2. Polaris (Similitud: 0.883044)
# 3. Novelists (Similitud: 0.839684)
# 4. Bury Tomorrow (Similitud: 0.761953)
# 5. Fit For A King (Similitud: 0.719099)
#
# ==================================================
# 🔎 Procesando artista: **Parker McCollum**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Parker McCollum
# Biografía (Resumen): Never Enough, Parker McCollum’s second major-label release, is a statement album. If its predecessor, Gold Chain Cowboy, announced Parker’s arrival in the country music mainstream, Never Enough (MCA Nashville) says that, damn right, he’s here to stay.
#
# Like Gold Chain Cowboy, it pairs Parker with producer Jon Randall (Miranda Lambert, Dierks Bentley), a fellow Texan who understands exactly what fuels Parker’s artistry: authenticity, vulnerability, and a little bit of defiance.
# Playcount Total (Last.fm): 4363722
# Número de Oyentes Únicos: 135679
#
# --- ARTISTAS SIMILARES ---
# 1. Koe Wetzel (Similitud: 1)
# 2. Riley Green (Similitud: 0.987561)
# 3. Cody Johnson (Similitud: 0.986429)
# 4. Flatland Cavalry (Similitud: 0.763085)
# 5. Bailey Zimmerman (Similitud: 0.711348)
#
# ==================================================
# 🔎 Procesando artista: **Tory Lanez**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Tory Lanez
# Biografía (Resumen): Tory Lanez was born Daystar Peterson on July 27th, 1992 to his father, Sonstar Peterson and his mother, Luella Peterson in Toronto, Canada. At the age of 11, Tory discovered that his mother was ill with a rare disease that affects  four in every one million people. With the devastating loss of his mother and the absence of this father who is an ordained minister, Tory was forced to provide for himself at the early age of fourteen. Although his dad was not present in his everyday life
# Playcount Total (Last.fm): 131293258
# Número de Oyentes Únicos: 1836067
#
# --- ARTISTAS SIMILARES ---
# 1. Bryson Tiller (Similitud: 1)
# 2. PARTYNEXTDOOR (Similitud: 0.892456)
# 3. Drake (Similitud: 0.697608)
# 4. A Boogie wit da Hoodie (Similitud: 0.675105)
# 5. Don Toliver (Similitud: 0.645763)
#
# ==================================================
# 🔎 Procesando artista: **Luke Bryan**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Luke Bryan
# Biografía (Resumen): Luke Bryan is a country singer, songwriter, and television personality. He is one of the world's best-selling music artists, with over 75 million records sold. His first ten albums – I'll Stay Me (2007), Doin' My Thing (2009), Tailgates & Tanlines (2011), Crash My Party (2013), Spring Break...Here to Party (2013), Spring Break...Checkin' Out (2015), Kill the Lights (2015), Farm Tour... Here's to the Farmer (2016), What Makes You Country (2017), and Born Here Live Here Die Here (2020) – have included 30 #1 hits.
# Playcount Total (Last.fm): 24694251
# Número de Oyentes Únicos: 1094924
#
# --- ARTISTAS SIMILARES ---
# 1. Jason Aldean (Similitud: 1)
# 2. Florida Georgia Line (Similitud: 0.995953)
# 3. Dierks Bentley (Similitud: 0.877716)
# 4. Lee Brice (Similitud: 0.850375)
# 5. Cole Swindell (Similitud: 0.831110)
#
# ==================================================
# 🔎 Procesando artista: **Amorphis**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Amorphis
# Biografía (Resumen): Amorphis is a Finnish progressive folk metal band started by Jan Rechberger, Tomi Koivusaari and Esa Holopainen in Helsinki, Finland in 1990. Amorphis absorbed and incorporated influences from many metal genres, and with time passing their sound evolved dramatically. Initially, the band was a Death Metal act, but with time they have evolved into making music that is more classifiable as Doom Metal with folk influences, and, more recently, Folk Metal and Symphonic Metal, utilizing increasingly complex arrangements and a less brutal sound.
# Playcount Total (Last.fm): 44384012
# Número de Oyentes Únicos: 554318
#
# --- ARTISTAS SIMILARES ---
# 1. Insomnium (Similitud: 1)
# 2. Dark Tranquillity (Similitud: 0.914700)
# 3. Paradise Lost (Similitud: 0.825577)
# 4. In Mourning (Similitud: 0.811707)
# 5. Sentenced (Similitud: 0.800422)
#
# ==================================================
# 🔎 Procesando artista: **The Chainsmokers**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: The Chainsmokers
# Biografía (Resumen): A production duo featuring Andrew Taggart and Alex Pall, the Chainsmokers mix dance and pop into a chart-topping sound that spawned hits like "Roses," "Closer," and "Don't Let Me Down." Pall and Taggart first made a name for themselves by creating remixes of their favorite indie bands that garnered tens of millions of streams. The duo released its official debut single, "#Selfie," which celebrated and skewered 2010s narcissism, in January 2014. The
# Playcount Total (Last.fm): 82290738
# Número de Oyentes Únicos: 2621285
#
# --- ARTISTAS SIMILARES ---
# 1. Martin Garrix (Similitud: 1)
# 2. Gryffin (Similitud: 0.935822)
# 3. Jonas Blue (Similitud: 0.842018)
# 4. Kygo (Similitud: 0.752831)
# 5. Zedd (Similitud: 0.749363)
#
# ==================================================
# 🔎 Procesando artista: **Whiskey Myers**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Whiskey Myers
# Biografía (Resumen): Whiskey Myers is an American southern rock group from Tyler, Texas composed of Cody Cannon, Cody Tate, John Jeffers, Jeff Hogg and Gary Brown. In 2008, they signed with Smith Entertainment and released their debut album, Road of Life. Their second album, Firewater, was released by Wiggy Thump in 2011 and debuted in the Top 30 on the Billboard Top Country Albums chart.
#
# In a modest rent house in the small East Texas town of Elkhart, Texas, Cody Cannon and Cody Tate began to write music, only dreaming of the success that is sure to follow.
# Playcount Total (Last.fm): 4347781
# Número de Oyentes Únicos: 189719
#
# --- ARTISTAS SIMILARES ---
# 1. Koe Wetzel (Similitud: 1)
# 2. Treaty Oak Revival (Similitud: 0.873974)
# 3. The Steel Woods (Similitud: 0.865651)
# 4. Southall (Similitud: 0.827216)
# 5. The Red Clay Strays (Similitud: 0.725814)
#
# ==================================================
# 🔎 Procesando artista: **Justin Timberlake**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Justin Timberlake
# Biografía (Resumen): Justin Randall Timberlake (born January 31, 1981) is an American singer, songwriter, actor, record producer, and dancer. He is recognized as a prominent figure in popular music and has sold an estimated 88 million records worldwide.
#
# Born and raised in Memphis, Tennessee, Timberlake began his career on musical television programs as a child, including competing on "Star Search" and appearing on the Disney Channel's "The All New Mickey Mouse Club" in the early to mid-1990s.
# Playcount Total (Last.fm): 155117283
# Número de Oyentes Únicos: 5307749
#
# --- ARTISTAS SIMILARES ---
# 1. *NSYNC (Similitud: 1)
# 2. Usher (Similitud: 0.698015)
# 3. Robin Thicke (Similitud: 0.578021)
# 4. Timbaland (Similitud: 0.565778)
# 5. Jennifer Lopez (Similitud: 0.552021)
#
# ==================================================
# 🔎 Procesando artista: **Tyler Braden**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Tyler Braden
# Biografía (Resumen):
# Playcount Total (Last.fm): 979618
# Número de Oyentes Únicos: 79939
#
# --- ARTISTAS SIMILARES ---
# 1. Warren Zeiders (Similitud: 1)
# 2. Dylan Scott (Similitud: 0.962168)
# 3. Josh Ross (Similitud: 0.930820)
# 4. Tucker Wetmore (Similitud: 0.904801)
# 5. Chase Matthew (Similitud: 0.877291)
# Datos guardados en '../csv/datos_artistas_lastfm.csv'
# Columnas guardadas: ['artista', 'playcount', 'listeners', 'biografia_resumen', 'similares']
