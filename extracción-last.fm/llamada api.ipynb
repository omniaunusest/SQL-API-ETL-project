# %%
import requests #librerias necesarias
import pandas as pd
import sys 
# sys.exit(1) detiene la ejecución del script INMEDIATAMENTE al encontrar un error
# CRÍTICO (como un archivo faltante o una columna incorrecta), evitando que el programa
# intente continuar y falle después. El número '1' indica que la terminación fue por un error.


apikey = "b4fcada0293085a139072e5e87a365b4"
url = "http://ws.audioscrobbler.com/2.0/"

# lectura de archivo csv
ruta_csv_artistas = 'C:/Users/maria/Desktop/adalab/da-promo-60-modulo2-equipo3/extracción-spotify-spotipy/metal/metal_2018_2022_canciones.csv'
#cada una pone su ruta para analizar sus datos

try:
    df_artistas = pd.read_csv(ruta_csv_artistas) #dataframe de artistas desde la ruta de lectura
    
    artistas_con_duplicados = df_artistas['artista'].tolist() #hacemos de 'artista' una lista
    
    artistas_unicos_set = set(artistas_con_duplicados) #con set eliminamos los duplicados
    
    artistas_a_buscar = list(artistas_unicos_set) #aqui ya tenemos la lista limpia con artistas unicos para poder analizar
    
    print(f"✅ Se cargaron {len(artistas_con_duplicados)} registros de artistas (incluidos duplicados).")
    print(f"✨ Se analizarán {len(artistas_a_buscar)} artistas únicos.")

except FileNotFoundError: #los except nos indican que tipo de errores se ha encontrado a la hora de cargar el csv
    print(f"❌ ERROR CRÍTICO: No se encontró el archivo CSV en la ruta '{ruta_csv_artistas}'.")
    sys.exit(1) # El código de salida 1 indica que hubo un error.

except KeyError:
    print(f"❌ ERROR CRÍTICO: La columna 'artista' no se encontró en el archivo CSV.")
    print("Por favor, verifica que el encabezado de la columna en el CSV se llame exactamente 'artista'.")
    sys.exit(1)

except Exception as e:
    print(f"❌ ERROR CRÍTICO: Ocurrió un error inesperado al leer el CSV: {e}")
    sys.exit(1)

# ----------------------------------------------------
# 📌 PUNTO 1: Inicializar la lista para guardar los datos
# ----------------------------------------------------
resultados_api = []
ruta_csv_salida = 'datos_artistas_lastfm.csv' # Define la ruta y nombre del archivo de salida


#bucle para cargar todos los artistas (únicos)
for artista_actual in artistas_a_buscar:
    
    print(f"\n==================================================") #llamadas a la API
    print(f"🔎 Procesando artista: **{artista_actual}**")
    print(f"==================================================")

    # Inicializar un diccionario para los datos de este artista
    datos_artista = {"artista": artista_actual}
    
    #llamada para BIOGRAFIA
    params_info = { #estas lineas no se pueden modificar ya que son necesarias para que nos de la biografia completa
        "method": "artist.getInfo",
        "artist": artista_actual,
        "api_key": apikey,
        "format": "json",
        "autocorrect": 1
    }
    
    try:
        response_info = requests.get(url, params=params_info) 
        datos_info = response_info.json()

        if response_info.status_code == 200 and 'artist' in datos_info: #comprueba que la llamada haya sido exitosa
            info_artista = datos_info['artist']
            
            # --- Extracción y Guardado de datos de BIOGRAFÍA y ESTADÍSTICAS ---
            print("--- BIOGRAFÍA y ESTADÍSTICAS ---")
            biografia_corta = info_artista.get('bio', {}).get('summary', 'No disponible')
            biografia_limpia = biografia_corta.split('<a href')[0].strip()
            
            estadisticas = info_artista.get('stats', {})
            playcount = estadisticas.get('playcount')
            listeners = estadisticas.get('listeners')
            
            # 📌 PUNTO 2: Almacenar datos en el diccionario
            datos_artista['playcount'] = playcount
            datos_artista['listeners'] = listeners
            datos_artista['biografia_resumen'] = biografia_limpia
            
            print(f"Nombre: {info_artista.get('name')}")
            print(f"Biografía (Resumen): {biografia_limpia}")
            print(f"Playcount Total (Last.fm): {playcount}")
            print(f"Número de Oyentes Únicos: {listeners}")
            
        else:
            print(f"❌ Error al obtener info para {artista_actual}. Estado HTTP: {response_info.status_code}")
            datos_artista['playcount'] = None # Si falla, asignamos None para no dejar el campo vacío
            datos_artista['biografia_resumen'] = "API Error"
            
    except requests.RequestException as e:
        print(f"❌ Error de conexión al obtener info para {artista_actual}: {e}")
        datos_artista['playcount'] = None
        datos_artista['biografia_resumen'] = "Connection Error"


    # llamada artistas similares
    similares = {
        "method": "artist.getSimilar",
        "artist": artista_actual,
        "api_key": apikey,
        "format": "json",
        "limit": 5 # Obtener los 5 artistas más similares
    }
    
    # Inicializar la columna de similares
    datos_artista['similares'] = "" # Cadena vacía por defecto
    
    try:
        response_similar = requests.get(url, params=similares)
        datos_similar = response_similar.json()

        if response_similar.status_code == 200 and 'similarartists' in datos_similar:
            artistas_similares = datos_similar['similarartists']['artist']
            
            # Artistas Similares
            print("\n--- ARTISTAS SIMILARES ---")
            if artistas_similares:
                # Crear una lista de nombres de artistas similares y unirlos con coma
                nombres_similares = [similar.get('name') for similar in artistas_similares]
                datos_artista['similares'] = ", ".join(nombres_similares) # 📌 PUNTO 3: Guardar en el diccionario

                for i, similar in enumerate(artistas_similares):
                    print(f"{i+1}. {similar.get('name')} (Similitud: {similar.get('match')})")
            else:
                print("No se encontraron artistas similares.")
        else:
            print(f"❌ Error al obtener similares para {artista_actual}. Estado HTTP: {response_similar.status_code}")
            
    except requests.RequestException as e:
        print(f"❌ Error de conexión al obtener similares para {artista_actual}: {e}")

    # Añadir el diccionario de datos al listado general
    resultados_api.append(datos_artista)


#conversion a csv en el caso de que asi lo queramos
try:
    df_resultados = pd.DataFrame(resultados_api)
    df_resultados.to_csv(ruta_csv_salida, index=False, encoding='utf-8')
    print(f"Datos guardados en '{ruta_csv_salida}'")
    print(f"Columnas guardadas: {list(df_resultados.columns)}")

except Exception as e:
    print(f"\n❌ ERROR al guardar el CSV: {e}")
# Out:
# ✅ Se cargaron 367 registros de artistas (incluidos duplicados).
# ✨ Se analizarán 108 artistas únicos.
#
# ==================================================
# 🔎 Procesando artista: **Motionless In White**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Motionless in White
# Biografía (Resumen): Motionless in White is an American heavy metal band from Scranton, Pennsylvania, formed in 2004. The current lineup includes lead vocalist Chris Cerulli, guitarists Ryan Sitkowski and Ricky Olson, drummer Vinny Mauro, and bassist Justin Morrow. Cerulli is the only remaining member of the original formation. The band’s name was inspired by the Eighteen Visions song "Motionless and White."
#
# The band was initially signed to Fearless Records, under which they released their first three studio albums.
# Playcount Total (Last.fm): 54097681
# Número de Oyentes Únicos: 830847
#
# --- ARTISTAS SIMILARES ---
# 1. Ice Nine Kills (Similitud: 1)
# 2. The Plot in You (Similitud: 0.839318)
# 3. Bad Omens (Similitud: 0.798258)
# 4. Black Veil Brides (Similitud: 0.719366)
# 5. Dark Divine (Similitud: 0.714283)
#
# ==================================================
# 🔎 Procesando artista: **Ramirez**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Ramirez
# Biografía (Resumen): 1) a rapper from San Francisco.
# Ramirez or Rvmirxz (both forms are used) is a rapper and co-founder of the independent record label G*59 with Ruby da Cherry and $crim (which he was a part of from 2013-2025). He draws influences from UGK, Tommy Wright lll, Three 6 Mafia, Outkast, DJ Screw, KeKe, and Andre Nickatina. He is currently 28 years old and he gained underground fame from making two collaboration mixtapes with the $uicideboy$.
#
# 2) A Brazillian indie rock band from Rio de Janeiro.
# Playcount Total (Last.fm): 22573467
# Número de Oyentes Únicos: 603539
#
# --- ARTISTAS SIMILARES ---
# 1. Scrim (Similitud: 1)
# 2. Pouya & Ghostemane (Similitud: 0.258091)
# 3. Derek Pope (Similitud: 0.224738)
# 4. Gizmo (Similitud: 0.102925)
# 5. DJ Paul Elstak (Similitud: 0.094581)
#
# ==================================================
# 🔎 Procesando artista: **Celtian**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Celtian
# Biografía (Resumen): Celtian is a folk metal band from Spain founded in 2017 by the flautist Diego Palacio, and led on vocals by the singer Xana Lavey. Their sound is strongly inspired by bands that mix Heavy metal with folk music European as Wizard of Oz, Saurom, , among others. Eluveitie
#
# Celtian
# Country of origin:  Spain - Alcalá de Henares, Community of Madrid
# Formed in:  2017
# Genre:  Symphonic Folk Metal
# Current label: Maldito Records
#
# Compilation appearance(s):
# Playcount Total (Last.fm): 238705
# Número de Oyentes Únicos: 8382
#
# --- ARTISTAS SIMILARES ---
# 1. Saurom (Similitud: 1)
# 2. Warcry (Similitud: 0.809091)
# 3. Mägo de Oz (Similitud: 0.602866)
# 4. Tierra Santa (Similitud: 0.588415)
# 5. Saratoga (Similitud: 0.570283)
#
# ==================================================
# 🔎 Procesando artista: **Erick the Architect**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Erick The Architect
# Biografía (Resumen): Erick Elliott, better known as Erick Arc Elliott or Erick the Architect, is an American rapper and record producer of Jamaican descent from Brooklyn, New York. A third of the hip hop trio, Flatbush ZOMBiES, Elliot has also released several solo projects.
# Playcount Total (Last.fm): 2661120
# Número de Oyentes Únicos: 269448
#
# --- ARTISTAS SIMILARES ---
# 1. Flatbush ZOMBiES (Similitud: 1)
# 2. Meechy Darko (Similitud: 0.866531)
# 3. The Underachievers (Similitud: 0.709052)
# 4. CJ FLY (Similitud: 0.707910)
# 5. Nyck Caution (Similitud: 0.592957)
#
# ==================================================
# 🔎 Procesando artista: **Lèpoka**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Lèpoka
# Biografía (Resumen): Spanish folk metal band. They sound like Mago de Oz and Korpiklaani. This is the correct spelling of the name.
# Playcount Total (Last.fm): 21503
# Número de Oyentes Únicos: 1636
#
# --- ARTISTAS SIMILARES ---
# 1. Salduie (Similitud: 1)
# 2. Debler (Similitud: 0.933576)
# 3. Ekyrian (Similitud: 0.844411)
# 4. Abäk (Similitud: 0.640296)
# 5. HADADANZA (Similitud: 0.625877)
#
# ==================================================
# 🔎 Procesando artista: **Imminence**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Imminence
# Biografía (Resumen): Imminence is a Swedish metalcore band formed in Trelleborg, Sweden, in 2009. The group consists of vocalist Eddie Berg, lead guitarist Harald Barrett, rhythm guitarist Alex Arnoldsson, bassist Christian Höijer and drummer Peter Hanström. They are currently signed to Arising Empire and have released five studio albums. Their most recent studio album, The Black, was released on 12 May 2024.
#
# The band was started in 2009 by Harald Barrett, with singer Eddie Berg joining shortly after.
# Playcount Total (Last.fm): 10055411
# Número de Oyentes Únicos: 188025
#
# --- ARTISTAS SIMILARES ---
# 1. Currents (Similitud: 1)
# 2. Aviana (Similitud: 0.891215)
# 3. Architects (Similitud: 0.816047)
# 4. Silent Planet (Similitud: 0.810473)
# 5. Annisokay (Similitud: 0.806473)
#
# ==================================================
# 🔎 Procesando artista: **We Came As Romans**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: We Came as Romans
# Biografía (Resumen): We Came as Romans (often abbreviated as WCAR) is an American metalcore band from Troy, Michigan. Formed in 2005, the band has undergone one name change and multiple line-up changes. In 2016, they signed with SharpTone Records after being part of the Equal Vision Records roster since 2009.
#
# The band has released seven studio albums:
# To Plant a Seed (2009)
# Understanding What We've Grown to Be (2011)
# Tracing Back Roots (2013)
# We Came as Romans (2015)
# Playcount Total (Last.fm): 28208913
# Número de Oyentes Únicos: 799434
#
# --- ARTISTAS SIMILARES ---
# 1. Fit For A King (Similitud: 1)
# 2. Memphis May Fire (Similitud: 0.929312)
# 3. Blessthefall (Similitud: 0.852101)
# 4. Woe, Is Me (Similitud: 0.749183)
# 5. The Word Alive (Similitud: 0.736066)
#
# ==================================================
# 🔎 Procesando artista: **ZillaKami**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: ZillaKami
# Biografía (Resumen): Junius Rogers (born September 20, 1998), known professionally as ZillaKami, is an American rapper and singer from Bay Shore, New York, though he lived in New York City from 2016 to 2018/19. Best known for his striking grillz, being half of City Morgue, his eccentric persona, MBF association, and provocative lyrics & music videos—which often depict drug abuse, violence, and nudity—ZillaKami’s controversial style began gaining traction online in early 2018.
# Playcount Total (Last.fm): 21383896
# Número de Oyentes Únicos: 366153
#
# --- ARTISTAS SIMILARES ---
# 1. City Morgue (Similitud: 1)
# 2. SosMula (Similitud: 0.791332)
# 3. City Morgue, ZillaKami & SosMula (Similitud: 0.753663)
# 4. City Morgue & ZillaKami (Similitud: 0.407162)
# 5. ZillaKami & Lil Uzi Vert (Similitud: 0.363600)
#
# ==================================================
# 🔎 Procesando artista: **Germ**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Germ
# Biografía (Resumen): There are multiple artists with this name:
#
# 1) A project of Australian Tim Yatras (Austere, Grey Waters, ex-Nazxul, etc) that incorporates elements of depressive black metal, rock and electronic music. Germ was conceived in early 2006, and shortly afterward the "Raving Mad With Sadness" song appeared online. Since then Germ has remained out of the public eye, but in the Spring of 2009 he entered SLS Studios to record his debut album. However, the record was not completed until 2011.
# Playcount Total (Last.fm): 8506810
# Número de Oyentes Únicos: 302788
#
# --- ARTISTAS SIMILARES ---
# 1. Austere (Similitud: 1)
# 2. An Autumn for Crippled Children (Similitud: 0.885481)
# 3. Woods of Desolation (Similitud: 0.833098)
# 4. Heretoir (Similitud: 0.783662)
# 5. Ghost Bath (Similitud: 0.776511)
#
# ==================================================
# 🔎 Procesando artista: **KXLLSWXTCH**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Kxllswxtch
# Biografía (Resumen): Jonathan Robert Whitmer (born July 17, 1999), professionally known as Kxllswxtch, is a recording artist and songwriter from Orange County, California based in Miami, Florida. He is known for his screaming vocals and horror-inspired visuals often featuring knives and fighting.
#
# Kxllswxtch began making music in 2017 and quickly gained a local following. He dropped several songs before releasing his first EP InVain on SoundCloud. He would go on to make much of his earlier music private.
# Playcount Total (Last.fm): 16921726
# Número de Oyentes Únicos: 786626
#
# --- ARTISTAS SIMILARES ---
# 1. do not resurrect (Similitud: 1)
# 2. Kamaara (Similitud: 0.818699)
# 3. Faceless 1-7 (Similitud: 0.817966)
# 4. ruzlxn (Similitud: 0.733765)
# 5. XZARKHAN (Similitud: 0.677822)
#
# ==================================================
# 🔎 Procesando artista: **Def Leppard**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Def Leppard
# Biografía (Resumen): Def Leppard is an English rock band formed in 1976 in Sheffield. Since 1992, the band has consisted of Rick Savage (bass, backing vocals), Joe Elliott (lead vocals), Rick Allen (drums, backing vocals), Phil Collen (guitar, backing vocals), and Vivian Campbell (guitar, backing vocals). They established themselves as part of the new wave of British heavy metal movement of the early 1980s.
#
# The band's greatest commercial success came between the early 1980s and the early 1990s.
# Playcount Total (Last.fm): 45684372
# Número de Oyentes Únicos: 1779551
#
# --- ARTISTAS SIMILARES ---
# 1. Poison (Similitud: 1)
# 2. Ratt (Similitud: 0.848567)
# 3. Dokken (Similitud: 0.794803)
# 4. Van Halen (Similitud: 0.774026)
# 5. Tesla (Similitud: 0.765568)
#
# ==================================================
# 🔎 Procesando artista: **The Plot In You**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: The Plot in You
# Biografía (Resumen): The Plot in You is an American metalcore band formed in 2010 in Hancock County, Ohio. Originally a side project of former Before Their Eyes member Landon Tewers, the group is composed of Tewers, guitarist Josh Childress, bassist Ethan Yoder and drummer Michael Cooper.
#
# The Plot in You have released three EPs and five studio albums. Their debut EP Wife Beater was released in 2010, followed by their first studio album First Born in 2011, and second studio album Could You Watch Your Children Burn in 2013.
# Playcount Total (Last.fm): 18824222
# Número de Oyentes Únicos: 404756
#
# --- ARTISTAS SIMILARES ---
# 1. Landon Tewers (Similitud: 1)
# 2. Bad Omens (Similitud: 0.840983)
# 3. Currents (Similitud: 0.815990)
# 4. Motionless in White (Similitud: 0.809209)
# 5. Thousand Below (Similitud: 0.765561)
#
# ==================================================
# 🔎 Procesando artista: **TOOL**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Tool
# Biografía (Resumen): Tool is an American alternative metal/progressive metal band from Los Angeles. Formed in 1990, the group's line-up includes vocalist Maynard James Keenan, guitarist Adam Jones and drummer Danny Carey. Justin Chancellor has been the band's bassist since 1995, replacing their original bassist Paul D'Amour. Tool has won four Grammy Awards, performed worldwide tours, and produced albums topping the charts in several countries.
#
# To date, the band has released five studio albums, one EP and one box set.
# Playcount Total (Last.fm): 218494040
# Número de Oyentes Únicos: 2514785
#
# --- ARTISTAS SIMILARES ---
# 1. A Perfect Circle (Similitud: 1)
# 2. Puscifer (Similitud: 0.567599)
# 3. Rishloo (Similitud: 0.391223)
# 4. Karnivool (Similitud: 0.319161)
# 5. Gojira (Similitud: 0.298627)
#
# ==================================================
# 🔎 Procesando artista: **Brothers of Metal**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Brothers of Metal
# Biografía (Resumen): Brothers of Metal is a Swedish power metal band formed in 2012 from Falun. Their first album Prophecy of Ragnarök was released in November 2017. The band consists of three vocalists (two male, one female), three guitar players, a bass player, and a drummer. The band's visual style and lyrics are inspired by Vikings and Norse mythology, and are often purposefully over-the-top, which earns them both criticism and praise.
#
# Brothers of Metal formed in 2012 with a vision to create "true metal
# Playcount Total (Last.fm): 5212238
# Número de Oyentes Únicos: 135560
#
# --- ARTISTAS SIMILARES ---
# 1. Beast in Black (Similitud: 1)
# 2. Bloodbound (Similitud: 0.962745)
# 3. Orden Ogan (Similitud: 0.891094)
# 4. Gloryhammer (Similitud: 0.860338)
# 5. Battle Beast (Similitud: 0.772743)
#
# ==================================================
# 🔎 Procesando artista: **I Prevail**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: I Prevail
# Biografía (Resumen): I Prevail is an American metalcore band formed in Southfield, Michigan, in 2013. They released their first EP „Heart vs Mind” a year later. Their rise to popularity came after releasing a cover of Taylor Swift’s Blank Space (also in 2014), which ended up reaching certified platinum in the US. Since then, the band has released three albums:
# - Lifelines in 2016, which reached #15 on the Billboard 200,
# - Trauma in 2019, which became their most successful album yet - receiving both a Best Rock Album Grammy nomination
# Playcount Total (Last.fm): 29478252
# Número de Oyentes Únicos: 549646
#
# --- ARTISTAS SIMILARES ---
# 1. Wage War (Similitud: 1)
# 2. Beartooth (Similitud: 0.897986)
# 3. Memphis May Fire (Similitud: 0.854387)
# 4. We Came as Romans (Similitud: 0.773157)
# 5. Dayseeker (Similitud: 0.710908)
#
# ==================================================
# 🔎 Procesando artista: **Slaughter to Prevail**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Slaughter to Prevail
# Biografía (Resumen): 𝗦𝗹𝗮𝘂𝗴𝗵𝘁𝗲𝗿 𝘁𝗼 𝗣𝗿𝗲𝘃𝗮𝗶𝗹 — Russian Deathcore band. Originally formed in 2014 in Yekaterinburg, and now based in Orlando, Florida.
# The group debuted with an EP titled Chapters of Misery in 2015 and followed up two years later with a full-length album, Misery Sermon. Their second album, Kostolom, released in 2021. The band is currently signed to Sumerian Records.
#
# Discography:
# Chapters of Misery - EPs (2015) Misery Sermon - (2017)Kostolom - (2021)Live In Moscow - (2023) Grizzly - (2025)
# Playcount Total (Last.fm): 9896093
# Número de Oyentes Únicos: 249399
#
# --- ARTISTAS SIMILARES ---
# 1. Alex Terrible (Similitud: 1)
# 2. Lorna Shore (Similitud: 0.769306)
# 3. Brand of Sacrifice (Similitud: 0.757778)
# 4. PALEFACE SWISS (Similitud: 0.753167)
# 5. Signs of the Swarm (Similitud: 0.602457)
#
# ==================================================
# 🔎 Procesando artista: **Dayseeker**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Dayseeker
# Biografía (Resumen): Dayseeker is an American rock/post-hardcore band from Orange County, California, formed in 2012. The band consists of vocalist Rory Rodriguez, guitarist Gino Sgambelluri, bassist Ramone Valerio and drummer Zac Mayfield. They are currently signed to Spinefarm Records and have released six studio albums. Their latest album, Creature In The Black Night, was released on October 24th, 2025.
# Playcount Total (Last.fm): 13539079
# Número de Oyentes Únicos: 238293
#
# --- ARTISTAS SIMILARES ---
# 1. Rain City Drive (Similitud: 1)
# 2. Thousand Below (Similitud: 0.804487)
# 3. Caskets (Similitud: 0.782890)
# 4. Wind Walkers (Similitud: 0.781811)
# 5. Too Close to Touch (Similitud: 0.721213)
#
# ==================================================
# 🔎 Procesando artista: **Five Finger Death Punch**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Five Finger Death Punch
# Biografía (Resumen): Five Finger Death Punch, also known as 5FDP or FFDP, is an American heavy metal band from Las Vegas, Nevada, formed in 2005. The original lineup included vocalist Ivan Moody, rhythm guitarist Zoltan Bathory, lead guitarist Caleb Andrew Bingham, bassist Matt Snell, and drummer Jeremy Spencer. Bingham was replaced by guitarist Darrell Roberts in 2006, who was later succeeded by Jason Hook in 2009. Snell left the band in 2010 and was replaced by Chris Kael in 2011.
# Playcount Total (Last.fm): 77842001
# Número de Oyentes Únicos: 1535635
#
# --- ARTISTAS SIMILARES ---
# 1. Disturbed (Similitud: 1)
# 2. Godsmack (Similitud: 0.981358)
# 3. Bad Wolves (Similitud: 0.875897)
# 4. Hellyeah (Similitud: 0.614486)
# 5. Stone Sour (Similitud: 0.577729)
#
# ==================================================
# 🔎 Procesando artista: **Gojira**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Gojira
# Biografía (Resumen): There are multiple artists called Gojira;
#
# 1) Gojira is a metal band from Bayonne, France. Their lyrics focus on life, ecology, and spiritual themes. They were formed in 1996 by brothers Joe Duplantier (vocals and lead guitar) and Mario Duplantier (drums), Christian Andreu (guitar) and Alexandre Cornillon (bass guitar). Cornillon left the band in 2001 and Jean-Michel Labadie became their bass player. Genres that they have been associated with over their career include death metal, progressive metal, thrash metal and groove metal.
# Playcount Total (Last.fm): 79569298
# Número de Oyentes Únicos: 969706
#
# --- ARTISTAS SIMILARES ---
# 1. Meshuggah (Similitud: 1)
# 2. Mastodon (Similitud: 0.960679)
# 3. Opeth (Similitud: 0.918270)
# 4. Death (Similitud: 0.687294)
# 5. Lamb of God (Similitud: 0.685929)
#
# ==================================================
# 🔎 Procesando artista: **Savage Ga$p**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Savage Ga$p
# Biografía (Resumen): Gaspare Magaddino (December 29, 1998), better know by his stage name Savage Ga$p, is an American artist. Gasp is best known for song Pumpkins Scream In the Dead of Night featuring artist shinigami.
# Playcount Total (Last.fm): 6495635
# Número de Oyentes Únicos: 276537
#
# --- ARTISTAS SIMILARES ---
# 1. buffalo_farm (Similitud: 1)
# 2. Original God (Similitud: 0.802997)
# 3. Ronen (Similitud: 0.596114)
# 4. Powfu (Similitud: 0.578558)
# 5. I'm Geist (Similitud: 0.556233)
#
# ==================================================
# 🔎 Procesando artista: **Stratovarius**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Stratovarius
# Biografía (Resumen): Stratovarius is a power metal band from Finland. They became more popular in the '90s, and throughout their career have inspired upcoming power metal bands with their baroque arranged keyboard solos & Ritchie Blackmore-like guitar portions.
#
# Stratovarius was founded in Finland in 1984 from former members of the band Black Water. They went through a number of personnel and musical changes before the band found its own voice. In 1984, the name was changed to Stratovarius (a portmanteau of Stratocaster and Stradivarius), an idea of Stråhlman's.
# Playcount Total (Last.fm): 30500168
# Número de Oyentes Únicos: 630214
#
# --- ARTISTAS SIMILARES ---
# 1. Sonata Arctica (Similitud: 1)
# 2. HammerFall (Similitud: 0.822012)
# 3. Edguy (Similitud: 0.817148)
# 4. Helloween (Similitud: 0.796616)
# 5. Rhapsody (Similitud: 0.771027)
#
# ==================================================
# 🔎 Procesando artista: **Peyton Parrish**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Peyton Parrish
# Biografía (Resumen): I'm 20 years old from the state of Arizona! I'm a Country Pop Singer/Preformer making Covers currently while developing my Original music!
# Playcount Total (Last.fm): 2049436
# Número de Oyentes Únicos: 84059
#
# --- ARTISTAS SIMILARES ---
# 1. Jonathan Young (Similitud: 1)
# 2. Bad Wolves (Similitud: 0.495686)
# 3. Through Fire (Similitud: 0.387775)
# 4. Days of Jupiter (Similitud: 0.381707)
# 5. Cooper Alan (Similitud: 0.353431)
#
# ==================================================
# 🔎 Procesando artista: **Salduie**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Salduie
# Biografía (Resumen): From the lands of the ancient Sedetans, Salduie combine History and traditional instruments with all the forcefulness of modern metal with melodeath and djent influences.
#
# Musically, Salduie incorporates traditional wind and string instruments such as flutes, bagpipes, bouzouki, violin, mandolin or banjo to which lyrical and guttural voices are added. This, added to the base formed by seven-string guitars, bass and drums, gives rise to a powerful and epic sound, but also melodic.
# Playcount Total (Last.fm): 171337
# Número de Oyentes Únicos: 9848
#
# --- ARTISTAS SIMILARES ---
# 1. Lèpoka (Similitud: 1)
# 2. Ekyrian (Similitud: 0.893935)
# 3. Debler (Similitud: 0.845140)
# 4. HADADANZA (Similitud: 0.597763)
# 5. Abäk (Similitud: 0.509867)
#
# ==================================================
# 🔎 Procesando artista: **CORPSE**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Corpse
# Biografía (Resumen): There are at least six bands and one artist with the name Corpse:
#
# 1) Corpse Husband (born August 8, 1997), or simply Corpse, is an American YouTuber from San Diego, California who is part of a community of YouTubers known as Horror Narration Channels. He is well known for having a very deep or low-pitched bass voice.
#
# He made his musical debut in 2016, being featured on the single "Grim Grinning Ghost" by The Living Tombstone and Crusher P.
#
# In June 2020
# Playcount Total (Last.fm): 30272567
# Número de Oyentes Únicos: 702795
#
# --- ARTISTAS SIMILARES ---
# 1. Anguish (Similitud: 1)
# 2. GOTOU寄生獣 (Similitud: 0.666456)
# 3. Kamaara (Similitud: 0.527204)
# 4. CORPSE, Bring Me The Horizon (Similitud: 0.518130)
# 5. Corpse, Savage Ga$p (Similitud: 0.500127)
#
# ==================================================
# 🔎 Procesando artista: **Amorphis**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Amorphis
# Biografía (Resumen): Amorphis is a Finnish progressive folk metal band started by Jan Rechberger, Tomi Koivusaari and Esa Holopainen in Helsinki, Finland in 1990. Amorphis absorbed and incorporated influences from many metal genres, and with time passing their sound evolved dramatically. Initially, the band was a Death Metal act, but with time they have evolved into making music that is more classifiable as Doom Metal with folk influences, and, more recently, Folk Metal and Symphonic Metal, utilizing increasingly complex arrangements and a less brutal sound.
# Playcount Total (Last.fm): 44331523
# Número de Oyentes Únicos: 553972
#
# --- ARTISTAS SIMILARES ---
# 1. Insomnium (Similitud: 1)
# 2. Dark Tranquillity (Similitud: 0.897975)
# 3. Sentenced (Similitud: 0.803929)
# 4. In Mourning (Similitud: 0.800296)
# 5. Paradise Lost (Similitud: 0.768773)
#
# ==================================================
# 🔎 Procesando artista: **Kid Rock**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Kid Rock
# Biografía (Resumen): Kid Rock (born Robert James Ritchie on January 17, 1971 in Romeo, MI),  is an American singer-songwriter and rapper from Detroit with five Grammy Award nominations. Kid Rock is known for music that incorporates elements of hip-hop, rap metal, blues-rock, hard rock, southern rock, funk and country.
#
# Kid Rock released several studio albums from 1988 that mostly went unnoticed before his 1998 record 'Devil Without a Cause', released with Atlantic Records, sold 11 million albums behind the hits, "Bawitdaba","Cowboy," and "Only God Knows Why".
# Playcount Total (Last.fm): 15221830
# Número de Oyentes Únicos: 1158262
#
# --- ARTISTAS SIMILARES ---
# 1. Uncle Kracker (Similitud: 1)
# 2. Buckcherry (Similitud: 0.955922)
# 3. Theory of a Deadman (Similitud: 0.701647)
# 4. Nickelback (Similitud: 0.697432)
# 5. Bad Company (Similitud: 0.696771)
#
# ==================================================
# 🔎 Procesando artista: **Orbit Culture**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Orbit Culture
# Biografía (Resumen): Orbit Culture is a melodic death metal/groove metal band from Eksjö, Sweden. The idea of the band grew strong within singer & rhythm guitarist Niklas and lead guitarist Maximilian after messing around with some unpolished demos at home. At that time, Maximilian was currently playing with another local band called Abstract Noise, together with Orbit Culture’s fellow drummer Markus Bladh. Maximilian recruited Markus to join his new band, followed by the arrival of Christoffer Olsson on bass guitar.
# Playcount Total (Last.fm): 6033039
# Número de Oyentes Únicos: 121107
#
# --- ARTISTAS SIMILARES ---
# 1. Eye of the Enemy (Similitud: 1)
# 2. The Halo Effect (Similitud: 0.937016)
# 3. Bloodred Hourglass (Similitud: 0.828612)
# 4. Wolfheart (Similitud: 0.738245)
# 5. Parasite Inc. (Similitud: 0.731137)
#
# ==================================================
# 🔎 Procesando artista: **Sleep Token**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Sleep Token
# Biografía (Resumen): Sleep Token is an English rock band formed in London in 2016. The members remain anonymous, performing while wearing masks. The band self-released their debut EP "One" in 2016 and followed it with the EP "Two" in 2017 after signing with Basick Records.
#
# Sleep Token later signed with Spinefarm Records and released their first full-length album, "Sundowning," in 2019. This was followed by "This Place Will Become Your Tomb" in 2021. Their third album
# Playcount Total (Last.fm): 132180298
# Número de Oyentes Únicos: 750599
#
# --- ARTISTAS SIMILARES ---
# 1. breakk.away (Similitud: 1)
# 2. Bad Omens (Similitud: 0.748925)
# 3. Spiritbox (Similitud: 0.666782)
# 4. Sleep Theory (Similitud: 0.523204)
# 5. Thornhill (Similitud: 0.520280)
#
# ==================================================
# 🔎 Procesando artista: **The HU**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: The HU
# Biografía (Resumen): The HU ("human" in Mongol) is a Mongolian folk metal band formed in 2016. They use traditional Mongolian instrumentation, including the Morin khuur, Tovshuur and Mongolian throat singing, and call their style of music "hunnu rock". The name is inspired by the Hunnu, an ancient Mongol empire, known as Xiongnu in western culture. Some of the band's lyrics include old Mongolian war cries and poetry.
# Two videos on YouTube released in Autumn 2018, "Yuve Yuve Yu - 28 September" and "Wolf Totem - 16 November"
# Playcount Total (Last.fm): 4731718
# Número de Oyentes Únicos: 274665
#
# --- ARTISTAS SIMILARES ---
# 1. Nine Treasures (Similitud: 1)
# 2. Tengger Cavalry (Similitud: 0.758497)
# 3. Korpiklaani (Similitud: 0.403274)
# 4. Corvus Corax (Similitud: 0.400840)
# 5. Turisas (Similitud: 0.385434)
#
# ==================================================
# 🔎 Procesando artista: **Beast In Black**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Beast in Black
# Biografía (Resumen): Beast in Black is a metal band from Helsinki, Finland formed in 2015. Their current line-up consists of founding member Anton Kabanan (guitar), Yannis Papadopoulous (vocals), Kasperi Heikkinen (guitar), Mate Molnar (bass) and Atte Palokangas (drums). The only line-up change the band went through is when original drummer Sami Hänninen left the band in 2017 for medical reasons. The band released one ep (Power of the Beast) and three full length albums (Berserker in 2017, From Hell with Love in 2019 & Dark Connection in 2021).
# Playcount Total (Last.fm): 10159949
# Número de Oyentes Únicos: 190756
#
# --- ARTISTAS SIMILARES ---
# 1. Battle Beast (Similitud: 1)
# 2. Dynazty (Similitud: 0.696435)
# 3. Brothers of Metal (Similitud: 0.688485)
# 4. Bloodbound (Similitud: 0.605456)
# 5. Gloryhammer (Similitud: 0.565227)
#
# ==================================================
# 🔎 Procesando artista: **Angelus Apatrida**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Angelus Apatrida
# Biografía (Resumen): Born in March 2000, Angelus Apatrida became in a few years one of the most important Spanish thrash metal bands. Many demos and band members passed through the history of Angelus Apatrida, but it was in January 2003 when the band changed their attitude and image and decided to make a harder and faster music, nearer to that of bands like Pantera, Megadeth, Overkill, Anthrax or Annihilator.
#
# The first album Evil Unleashed (Maldito Records, March 2006) made the band one of the biggest thrash metal acts in Spain
# Playcount Total (Last.fm): 1360604
# Número de Oyentes Únicos: 44933
#
# --- ARTISTAS SIMILARES ---
# 1. Crisix (Similitud: 1)
# 2. Soziedad Alkoholika (Similitud: 0.698281)
# 3. Hatchet (Similitud: 0.594240)
# 4. Gama Bomb (Similitud: 0.532126)
# 5. Havok (Similitud: 0.517405)
#
# ==================================================
# 🔎 Procesando artista: **Wind Rose**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Wind Rose
# Biografía (Resumen): Wind Rose is an Italian metal band. Its music style varied from progressive metal on early albums to folk metal on the latest, while also featuring symphonic power metal influence. The band's lyrics are inspired by fantasy fiction, with especial emphasis on mythological dwarves.
#
# The name "Wind Rose" was chosen by Claudio, Daniele and Federico, the founding members of the band. They started practicing together in 2007 as a Dream Theater, Symphony X and Blind Guardian cover band, playing in a lot of live shows.
# Playcount Total (Last.fm): 4115685
# Número de Oyentes Únicos: 176605
#
# --- ARTISTAS SIMILARES ---
# 1. Gloryhammer (Similitud: 1)
# 2. Powerwolf (Similitud: 0.974033)
# 3. Brothers of Metal (Similitud: 0.926589)
# 4. Orden Ogan (Similitud: 0.787684)
# 5. Alestorm (Similitud: 0.764011)
#
# ==================================================
# 🔎 Procesando artista: **Bad Wolves**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Bad Wolves
# Biografía (Resumen): Bad Wolves is a metal supergroup, composed of lead singer Daniel "DL" Laskiewicz (ex-guitarist of The Acacia Strain), guitarists Doc Coyle (ex-God Forbid) and Chris Cain (Bury Your Dead), drummer John Boecklin (ex-Devildriver) , and bassist Kyle Konkiel.
# Their original lead singer, Tommy Vext, was dismissed from the band in January 2021 on account of his political beliefs and accusations of violence against him. Their debut album "Disobey" was released on May 11
# Playcount Total (Last.fm): 6447457
# Número de Oyentes Únicos: 354202
#
# --- ARTISTAS SIMILARES ---
# 1. Through Fire (Similitud: 1)
# 2. Five Finger Death Punch (Similitud: 0.943254)
# 3. Silent Theory (Similitud: 0.841339)
# 4. Gemini Syndrome (Similitud: 0.728503)
# 5. Light the Torch (Similitud: 0.667194)
#
# ==================================================
# 🔎 Procesando artista: **The Pretty Reckless**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: The Pretty Reckless
# Biografía (Resumen): The Pretty Reckless is an American alternative rock band from New York, United States. The current members are Taylor Momsen (lead vocals, rhythm guitar), Ben Phillips (lead guitar, backing vocals), Mark Damon (bass) and Jamie Perkins (drums). The band formed in 2009 when Momsen stated that she would quit acting after her television role Jenny Humphrey from the hit TV show Gossip Girl (2007-2012) to focus on her music career.
#
# In 2010, they released their debut studio album Light Me Up.
# Playcount Total (Last.fm): 55049128
# Número de Oyentes Únicos: 1236126
#
# --- ARTISTAS SIMILARES ---
# 1. Halestorm (Similitud: 1)
# 2. Dorothy (Similitud: 0.674994)
# 3. Evanescence (Similitud: 0.388501)
# 4. Dead Sara (Similitud: 0.387688)
# 5. DIAMANTE (Similitud: 0.364429)
#
# ==================================================
# 🔎 Procesando artista: **Mastodon**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Mastodon
# Biografía (Resumen): Mastodon is an American metal band from Atlanta, Georgia, formed in 2000. The group is composed of Troy Sanders (bass/vocals), Bill Kelliher (rhythm guitar/backing vocals), and Brann Dailor (drums/vocals). The band's lead guitarist was Brent Hinds from 1999-2025. Mastodon has released seven studio albums, as well as a number of other releases. The band's 2002 debut album, Remission, garnered significant critical acclaim for its unique sound. Mastodon's second full-length release
# Playcount Total (Last.fm): 83007321
# Número de Oyentes Únicos: 1221844
#
# --- ARTISTAS SIMILARES ---
# 1. Baroness (Similitud: 1)
# 2. Gojira (Similitud: 0.833746)
# 3. Opeth (Similitud: 0.585184)
# 4. The Ocean (Similitud: 0.525143)
# 5. Between the Buried and Me (Similitud: 0.495311)
#
# ==================================================
# 🔎 Procesando artista: **Black Label Society**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Black Label Society
# Biografía (Resumen): Black Label Society is a heavy metal band formed by former Ozzy Osbourne/Pride & Glory guitar player Zakk Wylde in Los Angeles, California in 1998. They have released ten albums to date, eight of which are studio albums. The band, aside from Wylde consists of bassist John "JD" Deservio, drummer Jeff Fabb, and rhythm guitarist Dario Lorina.
#
# The band is not to be confused with Zakk Wylde's solo project (sometimes known as Book of Shadows after its only album) or with Pride & Glory, Wylde's southern rock band.
# Playcount Total (Last.fm): 37339748
# Número de Oyentes Únicos: 976550
#
# --- ARTISTAS SIMILARES ---
# 1. Zakk Wylde (Similitud: 1)
# 2. Pride & Glory (Similitud: 0.896617)
# 3. Down (Similitud: 0.586564)
# 4. Pantera (Similitud: 0.464601)
# 5. Zakk Sabbath (Similitud: 0.415712)
#
# ==================================================
# 🔎 Procesando artista: **Accept**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Accept
# Biografía (Resumen): Accept is a German heavy metal band from Solingen, formed in 1976 by guitarist Wolf Hoffmann, vocalist Udo Dirkschneider, and bassist Peter Baltes. The group has its origins in the late 1960s under the earlier name Band X. Over the years, Accept has undergone numerous lineup changes. Hoffmann is the only original member to remain in the band and has performed on all of its albums. As of 2024, Accept’s lineup includes Hoffmann, vocalist Mark Tornillo
# Playcount Total (Last.fm): 21674449
# Número de Oyentes Únicos: 707977
#
# --- ARTISTAS SIMILARES ---
# 1. U.D.O. (Similitud: 1)
# 2. Saxon (Similitud: 0.745149)
# 3. Judas Priest (Similitud: 0.642115)
# 4. Running Wild (Similitud: 0.581258)
# 5. Manowar (Similitud: 0.573469)
#
# ==================================================
# 🔎 Procesando artista: **Diggy Graves**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Diggy Graves
# Biografía (Resumen): Raised in the PNW, 30 year old Diggy Graves likes to describe his music as a melting pot of genres that ranges from rap to horror core. Diggy has been making music for most of his life and decided to create his persona behind the mask in 2020. You might know him from his most popular songs Red Vineyard and Circus Psycho. You can usually find him hidden in the woods making music in his cabin. He always looks forward to performing live and seeing all his loyal fans.
# Playcount Total (Last.fm): 1307522
# Número de Oyentes Únicos: 46482
#
# --- ARTISTAS SIMILARES ---
# 1. $carecrow (Similitud: 1)
# 2. Resentvul (Similitud: 0.856442)
# 3. Witchouse 40k (Similitud: 0.654141)
# 4. Kill Dyll (Similitud: 0.630472)
# 5. Grim Salvo (Similitud: 0.536233)
#
# ==================================================
# 🔎 Procesando artista: **Parkway Drive**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Parkway Drive
# Biografía (Resumen): Parkway Drive is a metalcore band from Byron Bay, Australia.
#
# The band formed in the summer of 2003, their name coming from the street they used to practice on in their home town of Byron Bay, Australia. Not long after they had formed, they released a split EP with Adelaide band I Killed The Prom Queen. Later that year, the band also made an appearance on the Byron Bay Hardcore compilation What We've Built, preceded by their debut EP, Don't Close Your Eyes.
# Playcount Total (Last.fm): 68544905
# Número de Oyentes Únicos: 865245
#
# --- ARTISTAS SIMILARES ---
# 1. Bury Tomorrow (Similitud: 1)
# 2. The Ghost Inside (Similitud: 0.927732)
# 3. As I Lay Dying (Similitud: 0.894901)
# 4. Architects (Similitud: 0.822759)
# 5. August Burns Red (Similitud: 0.794186)
#
# ==================================================
# 🔎 Procesando artista: **Papa Roach**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Papa Roach
# Biografía (Resumen): Papa Roach is an American rock band from Vacaville, California, formed in 1993. The original lineup consisted of lead vocalist Jacoby Shaddix, guitarist Jerry Horton, drummer Dave Buckner, bassist Will James, and trombonist Ben Luther.
#
# After two EPs, James left and was replaced by Tobin Esperance. The band independently released two more EPs before signing with DreamWorks Records in 1999, subsequently releasing the triple-platinum Infest in 2000, the gold album Lovehatetragedy in 2002 and the platinum album Getting Away with Murder in 2004.
# Playcount Total (Last.fm): 123861877
# Número de Oyentes Únicos: 3588922
#
# --- ARTISTAS SIMILARES ---
# 1. Three Days Grace (Similitud: 1)
# 2. P.O.D. (Similitud: 0.834128)
# 3. Shinedown (Similitud: 0.832843)
# 4. Pop Evil (Similitud: 0.794557)
# 5. Saint Asonia (Similitud: 0.776356)
#
# ==================================================
# 🔎 Procesando artista: **Ghost**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Ghost
# Biografía (Resumen): 1) Ghost, also formerly known as Ghost B.C. in the United States, is a Swedish metal band that was formed in Linköping in 2006. In 2010, they released a three-track demo followed by a 7-inch vinyl titled "Elizabeth", and later their debut full-length album Opus Eponymous. The song "Ritual" was chosen by Kerrang! as one of "The 50 Most Evil Songs Ever." The Grammis-nominated album was widely praised and significantly increased their popularity. Their second album and major label debut
# Playcount Total (Last.fm): 145570949
# Número de Oyentes Únicos: 1541128
#
# --- ARTISTAS SIMILARES ---
# 1. Volbeat (Similitud: 1)
# 2. Ozzy Osbourne (Similitud: 0.786800)
# 3. Metallica (Similitud: 0.748631)
# 4. Avenged Sevenfold (Similitud: 0.745256)
# 5. Iron Maiden (Similitud: 0.707338)
#
# ==================================================
# 🔎 Procesando artista: **Fit For A King**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Fit For A King
# Biografía (Resumen): Fit For A King is a metalcore band from Dallas, Texas, United States formed in 2007. The band comprises vocalist Ryan Kirby, bassist-vocalist Ryan "Tuck" O'Leary, guitarists Bobby Lynge and Daniel Gailey, and drummer Trent Celaya.
#
# The band was formed in Dallas, Texas in 2007 by Jared Easterling, Aaron Decur, Justin Juno, Jared McFerron, Alex Danforth and Jed McNeill. The band had performed locally and regionally and released two EPs in their beginning years.
# Playcount Total (Last.fm): 11122591
# Número de Oyentes Únicos: 236567
#
# --- ARTISTAS SIMILARES ---
# 1. Wage War (Similitud: 1)
# 2. Kingdom of Giants (Similitud: 0.913569)
# 3. We Came as Romans (Similitud: 0.884434)
# 4. Bury Tomorrow (Similitud: 0.864767)
# 5. Currents (Similitud: 0.852835)
#
# ==================================================
# 🔎 Procesando artista: **Skindred**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Skindred
# Biografía (Resumen): Skindred is a four-piece "ragga metal" band from Newport, Wales. Their genre is an innovative mix of metal, punk, and reggae. The band was formed in 1999 following the disbandment of vocalist Benji Webbe's previous band, Dub War and his one-off side-project Mass Mental? featuring Robert Trujillo (Suicidal Tendencies, Infectious Grooves, Metallica) released the year prior.
#
# The band initially came together with three of the four Dub War veterans with Jeff Rose and Martin Ford returning alongside Webbe, along with new bassist Daniel Pugsley.
# Playcount Total (Last.fm): 15716049
# Número de Oyentes Únicos: 611078
#
# --- ARTISTAS SIMILARES ---
# 1. Soil (Similitud: 1)
# 2. Nonpoint (Similitud: 0.751291)
# 3. Dope (Similitud: 0.652268)
# 4. Dub War (Similitud: 0.636070)
# 5. Clawfinger (Similitud: 0.626725)
#
# ==================================================
# 🔎 Procesando artista: **Motörhead**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Motörhead
# Biografía (Resumen): Motörhead was an English metal band formed in London in 1975 by bassist and lead vocalist Lemmy Kilmister, guitarist Larry Wallis and drummer Lucas Fox. Lemmy was also the primary songwriter and only constant member. The band are often considered a precursor to the new wave of British heavy metal, which re-energised heavy metal in the late 1970s and early 1980s. Though several guitarists and drummers have played in Motörhead, most of their best-selling
# Playcount Total (Last.fm): 80281286
# Número de Oyentes Únicos: 2098062
#
# --- ARTISTAS SIMILARES ---
# 1. Judas Priest (Similitud: 1)
# 2. Saxon (Similitud: 0.820389)
# 3. Black Sabbath (Similitud: 0.745884)
# 4. Dio (Similitud: 0.711121)
# 5. Accept (Similitud: 0.668878)
#
# ==================================================
# 🔎 Procesando artista: **Godsmack**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Godsmack
# Biografía (Resumen): Godsmack is an American rock band from Lawrence, Massachusetts, formed in 1995. The band is currently composed of lead singer and rhythm guitarist Sully Erna and bassist Robbie Merrill. Since its formation, Godsmack has released eight studio albums, one EP (The Other Side), four DVDs, one compilation album (Good Times, Bad Times... Ten Years of Godsmack), and one live album (Live & Inspired).
#
# The band has released three consecutive number-one albums (Faceless, IV and The Oracle) on the Billboard 200.
# Playcount Total (Last.fm): 55599027
# Número de Oyentes Únicos: 1993699
#
# --- ARTISTAS SIMILARES ---
# 1. Drowning Pool (Similitud: 1)
# 2. Disturbed (Similitud: 0.970490)
# 3. Five Finger Death Punch (Similitud: 0.947716)
# 4. Sully Erna (Similitud: 0.825295)
# 5. Soil (Similitud: 0.772655)
#
# ==================================================
# 🔎 Procesando artista: **Lamb of God**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Lamb of God
# Biografía (Resumen): Lamb of God is an American groove metal band, originally formed under the name Burn the Priest.
#
# The roots of Lamb of God were planted in the year 1990, when Mark Morton, Chris Adler and John Campbell were friends at Virginia Commonwealth University. The trio began playing at Adler's house in Richmond weathering chilly conditions. "There was no heat in the house," recalls Campbell. "We would hang around the kerosene heaters, get really drunk and write metal songs. Fumes and Black Label beer were definitely what fueled our early days."
# Playcount Total (Last.fm): 79964371
# Número de Oyentes Únicos: 1422192
#
# --- ARTISTAS SIMILARES ---
# 1. Burn the Priest (Similitud: 1)
# 2. DevilDriver (Similitud: 0.821590)
# 3. Chimaira (Similitud: 0.757468)
# 4. Machine Head (Similitud: 0.729752)
# 5. Trivium (Similitud: 0.606259)
#
# ==================================================
# 🔎 Procesando artista: **Apocalyptica**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Apocalyptica
# Biografía (Resumen): Apocalyptica is a band from Helsinki, Finland consisting of three classically-trained cellists and a drummer. Their speciality is heavy metal music on cellos, though they also play classical music.
#
# They started in 1993 by playing covers of Metallica, but once the concept became popular they wrote their own original works, maintaining the thrash metal influences on their albums Inquisition Symphony (mainly covers as well) and Cult. Since Reflections they have added drums to their recordings and live performances.
# Playcount Total (Last.fm): 69279365
# Número de Oyentes Únicos: 1612760
#
# --- ARTISTAS SIMILARES ---
# 1. Nightwish (Similitud: 1)
# 2. Epica (Similitud: 0.984126)
# 3. Tarja (Similitud: 0.925029)
# 4. Within Temptation (Similitud: 0.903536)
# 5. Therion (Similitud: 0.815080)
#
# ==================================================
# 🔎 Procesando artista: **Within Temptation**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Within Temptation
# Biografía (Resumen): Within Temptation is a Dutch symphonic metal/rock band founded in April 1996 by vocalist Sharon den Adel and guitarist Robert Westerholt.
#
# The band went through numerous style changes, blending various genres throughout its career. Their debut album Enter and early singles were in vein of gothic metal.  From Mother Earth (2000) album onwards, the band shifted to symphonic metal genre, which brought Within Temptation to popularity. Their recent albums, starting with The Unforgiving (2011), lean towards  alternative rock  and  synth rock .
# Playcount Total (Last.fm): 101318366
# Número de Oyentes Únicos: 1354959
#
# --- ARTISTAS SIMILARES ---
# 1. Delain (Similitud: 1)
# 2. Xandria (Similitud: 0.867804)
# 3. Nightwish (Similitud: 0.853542)
# 4. Epica (Similitud: 0.834787)
# 5. Tarja (Similitud: 0.757042)
#
# ==================================================
# 🔎 Procesando artista: **Machine Head**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Machine Head
# Biografía (Resumen): Machine Head is an American metal band from Oakland, California. The band was formed in 1991 by vocalist/guitarist Robb Flynn and bassist Adam Duce. The band's aggressive musicianship made it one of the pioneering bands in the new wave of American heavy metal, and it is also considered to be part of the second wave of thrash metal bands from the 1990s. Machine Head's current lineup comprises Flynn and bassist Jared MacEachern. Duce, guitarists Logan Mader
# Playcount Total (Last.fm): 49801536
# Número de Oyentes Únicos: 1192150
#
# --- ARTISTAS SIMILARES ---
# 1. Chimaira (Similitud: 1)
# 2. Lamb of God (Similitud: 0.913996)
# 3. Trivium (Similitud: 0.900222)
# 4. Soulfly (Similitud: 0.828111)
# 5. DevilDriver (Similitud: 0.785067)
#
# ==================================================
# 🔎 Procesando artista: **Spiritbox**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Spiritbox
# Biografía (Resumen): Spiritbox is an alternative metal / metalcore / progressive metal band from Victoria, British Columbia, formed in 2017 by vocalist Courtney LaPlante and guitarist Mike Stringer.
#
# Current lineup includes Courtney LaPlante, Mike Stringer, bassist Josh Gilbert, and drummer Zev Rosenberg. Former members have included Ryan Loerke (drums, 2018–2020) and Bill Crook (bass, 2018–2022).
#
# They released their debut EP Spiritbox (2017), followed by Singles Collection (2019).
# Playcount Total (Last.fm): 40006293
# Número de Oyentes Únicos: 492560
#
# --- ARTISTAS SIMILARES ---
# 1. Thornhill (Similitud: 1)
# 2. Silent Planet (Similitud: 0.973099)
# 3. Architects (Similitud: 0.962882)
# 4. Sleep Token (Similitud: 0.941325)
# 5. ERRA (Similitud: 0.915339)
#
# ==================================================
# ...
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Bring Me the Horizon
# Biografía (Resumen): Bring Me the Horizon is a British metalcore/pop rock/electronic band formed in Sheffield, England, in 2004. The group currently consists of lead vocalist Oli Sykes, drummer Matt Nicholls, guitarist Lee Malia, and bassist Matt Kean. They are signed to RCA Records globally and to Columbia Records in the United States.
#
# The band released its debut album "Count Your Blessings" in 2006. The album featured a deathcore style that received mixed reactions and generally unfavorable reviews from critics.
# Playcount Total (Last.fm): 300139927
# Número de Oyentes Únicos: 2689601
#
# --- ARTISTAS SIMILARES ---
# 1. Bad Omens (Similitud: 1)
# 2. The Plot in You (Similitud: 0.890586)
# 3. Motionless in White (Similitud: 0.769243)
# 4. Asking Alexandria (Similitud: 0.660623)
# 5. Architects (Similitud: 0.593288)
#
# ==================================================
# 🔎 Procesando artista: **WWE**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: WWE
# Biografía (Resumen): World Wrestling Entertainment, LLC. (WWE) is a publicly-traded, privately-controlled integrated media (focusing in television, Internet, and live events) and sports entertainment company dealing primarily in professional wrestling, with major revenue sources also coming from film, music, product licensing, and direct product sales.
#
# The vast majority of music used at WWE events is written and recorded by artists either working for WWE directly (such as Jimmy Hart
# Playcount Total (Last.fm): 15995290
# Número de Oyentes Únicos: 454347
#
# --- ARTISTAS SIMILARES ---
# 1. All Elite Wrestling (Similitud: 1)
# 2. Joe Hendry (Similitud: 0.757946)
# 3. WWE & Jim Johnston (Similitud: 0.496671)
# 4. Jim Johnston (Similitud: 0.384367)
# 5. CFO$ (Similitud: 0.169190)
#
# ==================================================
# 🔎 Procesando artista: **Eluveitie**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Eluveitie
# Biografía (Resumen): Eluveitie is a folk metal band from Winterthur, Switzerland. The founder of this band was Chrigel Glanzmann. The band formed in 2002 and their first EP, "Vên" came out in 2003. They describe themselves as "The new wave of folk metal". The band then released a full-length album, "Spirit" in June 2006. In November 2007, Eluveitie was signed by Nuclear Blast. The first product of the collaboration, "Slania", was released in February 2008. The album peaked at number 35 in the Swiss charts and number 72 in the German charts.
# Playcount Total (Last.fm): 48140973
# Número de Oyentes Únicos: 520580
#
# --- ARTISTAS SIMILARES ---
# 1. Ensiferum (Similitud: 1)
# 2. Equilibrium (Similitud: 0.830848)
# 3. Korpiklaani (Similitud: 0.796942)
# 4. SuidAkrA (Similitud: 0.738706)
# 5. Cruachan (Similitud: 0.669126)
#
# ==================================================
# 🔎 Procesando artista: **Trivium**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Trivium
# Biografía (Resumen): Trivium is a heavy metal band which formed in Orlando, Florida, United States in 1999. The band currently consists of Matt Heafy (vocals, guitar), Corey Beaulieu (guitar), Paolo Gregoletto (bass) and Alex Bent (drums). Heafy is the band's only remaining original member.
#
# Trivium crosses multiple heavy metal genres such as thrash metal, alternative metal, groove metal, and heavy metal. Their style has evolved over the years from their earliest work on Ember to Inferno right through to In Waves.
# Playcount Total (Last.fm): 80576246
# Número de Oyentes Únicos: 1337092
#
# --- ARTISTAS SIMILARES ---
# 1. Bullet for My Valentine (Similitud: 1)
# 2. Killswitch Engage (Similitud: 0.956278)
# 3. All That Remains (Similitud: 0.847505)
# 4. As I Lay Dying (Similitud: 0.808946)
# 5. Machine Head (Similitud: 0.775218)
#
# ==================================================
# 🔎 Procesando artista: **DragonForce**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: DragonForce
# Biografía (Resumen): DragonForce is a British power metal band based in London, England. Formed in 1999, the group is known for their long and fast guitar solos, fantasy-themed lyrics, and electronic sounds in their music to add to their retro video game-influenced sound. DragonForce has released seven studio albums, two live albums, one compilation album, one live DVD and one demo.
#
# History - Early years and Valley of the Damned (1999–2003).
# DragonForce was founded in 1999 by guitarists Herman Li and Sam Totman, under the name of DragonHeart.
# Playcount Total (Last.fm): 38756513
# Número de Oyentes Únicos: 1132591
#
# --- ARTISTAS SIMILARES ---
# 1. Twilight Force (Similitud: 1)
# 2. Freedom Call (Similitud: 0.795940)
# 3. Gloryhammer (Similitud: 0.788110)
# 4. Rhapsody of Fire (Similitud: 0.686155)
# 5. Sonata Arctica (Similitud: 0.677004)
#
# ==================================================
# 🔎 Procesando artista: **Rammstein**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Rammstein
# Biografía (Resumen): Rammstein is a German Neue Deutsche Härte band formed in Berlin in 1994. The group’s lineup—consisting of Till Lindemann (lead vocals), Richard Kruspe (lead guitar), Paul Landers (rhythm guitar), Oliver Riedel (bass), Christoph Schneider (drums), and Christian "Flake" Lorenz (keyboards)—has remained unchanged throughout their career. Their songwriting process typically involves Lindemann composing and performing lyrics to instrumental arrangements written by the rest of the band.
# Playcount Total (Last.fm): 309956266
# Número de Oyentes Únicos: 3006046
#
# --- ARTISTAS SIMILARES ---
# 1. Lindemann (Similitud: 1)
# 2. Till Lindemann (Similitud: 0.792295)
# 3. Emigrate (Similitud: 0.619938)
# 4. Eisbrecher (Similitud: 0.473082)
# 5. OOMPH! (Similitud: 0.428405)
#
# ==================================================
# 🔎 Procesando artista: **From Ashes to New**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: From Ashes to New
# Biografía (Resumen): Alt/nu-metal band from Pennsylvania, formed by and centred around vocalist/guitarist Matt Brandyberry.
#
# The idea behind From Ashes to New, was to do something fresh and meaningful. By taking every kind of music that influences them, FATN is able to create a sound that is not only refreshing but also makes you feel as if you've known it all along. With songs geared toward everyday struggles and uplifting lyrics in the direction of self betterment; From Ashes to New looks to capture the attention of listeners from all walks of music.
# Playcount Total (Last.fm): 6436161
# Número de Oyentes Únicos: 239909
#
# --- ARTISTAS SIMILARES ---
# 1. Silent Theory (Similitud: 1)
# 2. Through Fire (Similitud: 0.746432)
# 3. Fight the Fade (Similitud: 0.713140)
# 4. Sleep Theory (Similitud: 0.616915)
# 5. From Fall to Spring (Similitud: 0.585919)
#
# ==================================================
# 🔎 Procesando artista: **As I Lay Dying**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: As I Lay Dying
# Biografía (Resumen): As I Lay Dying is an American metalcore band from San Diego, California, formed in 2000 by vocalist Tim Lambesis. The first complete lineup, which included drummer Jordan Mancino, was established in 2001. The band has released eight studio albums, one split album, and two compilation albums.
#
# The fourth studio album, "An Ocean Between Us," peaked at number 8 on the Billboard 200 and number 1 on the Top Rock chart. The band has performed at festivals including Wacken Open Air
# Playcount Total (Last.fm): 63144878
# Número de Oyentes Únicos: 1105891
#
# --- ARTISTAS SIMILARES ---
# 1. All That Remains (Similitud: 1)
# 2. Unearth (Similitud: 0.881036)
# 3. Killswitch Engage (Similitud: 0.847591)
# 4. August Burns Red (Similitud: 0.837467)
# 5. Miss May I (Similitud: 0.800139)
#
# ==================================================
# 🔎 Procesando artista: **Ozzy Osbourne**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Ozzy Osbourne
# Biografía (Resumen): Ozzy Osbourne (born John Michael Osbourne in Marston Green, Warwickshire, on 3 December 1948; died 22 July 2025) was an English singer, songwriter, and media personality remembered as the lead vocalist of the heavy metal band Black Sabbath, during which period he adopted the nickname "Prince of Darkness". On 5 July 2025, Osbourne performed his final show at the "Back to the Beginning" concert event.
#
# He was inducted into the Rock and Roll Hall of Fame as a member of Black Sabbath in 2006 and as a solo artist in 2024.
# Playcount Total (Last.fm): 90608277
# Número de Oyentes Únicos: 3003049
#
# --- ARTISTAS SIMILARES ---
# 1. Black Sabbath (Similitud: 1)
# 2. Dio (Similitud: 0.419729)
# 3. Judas Priest (Similitud: 0.339790)
# 4. Iron Maiden (Similitud: 0.331849)
# 5. Kiss (Similitud: 0.319077)
#
# ==================================================
# 🔎 Procesando artista: **Arch Enemy**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Arch Enemy
# Biografía (Resumen): Arch Enemy is a Swedish melodic death metal band, originally a supergroup from Halmstad, formed in 1995. Its members were in bands such as Carcass, Armageddon, Carnage, Mercyful Fate, Spiritual Beggars, The Agonist, Nevermore, and Eucharist. It was founded by Carcass guitarist Michael Amott along with Johan Liiva, who were both originally from the death metal band Carnage. The band has released eleven studio albums, three live albums, three video albums and four EPs.
# Playcount Total (Last.fm): 60746239
# Número de Oyentes Únicos: 899244
#
# --- ARTISTAS SIMILARES ---
# 1. Amon Amarth (Similitud: 1)
# 2. The Halo Effect (Similitud: 0.826634)
# 3. In Flames (Similitud: 0.816758)
# 4. Soilwork (Similitud: 0.789914)
# 5. Dark Tranquillity (Similitud: 0.789521)
#
# ==================================================
# 🔎 Procesando artista: **Amon Amarth**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Amon Amarth
# Biografía (Resumen): Amon Amarth is a Swedish melodic death metal band from Tumba, formed in 1992. The band takes its name from the Sindarin name of Mount Doom, a volcano in J. R. R. Tolkien's Middle-earth. Their lyrics mostly deal with Viking mythology and history, and so they have been sometimes erroneously labeled "Viking metal", although the band insists they play melodic death metal.
#
# The band is composed of lead guitarist Olavi Mikkonen, vocalist Johan Hegg, bassist Ted Lundström, rhythm guitarist Johan Söderberg, and drummer Jocke Wallgren.
# Playcount Total (Last.fm): 74099783
# Número de Oyentes Únicos: 822908
#
# --- ARTISTAS SIMILARES ---
# 1. Arch Enemy (Similitud: 1)
# 2. Ensiferum (Similitud: 0.932286)
# 3. Insomnium (Similitud: 0.897470)
# 4. Dark Tranquillity (Similitud: 0.864901)
# 5. Kalmah (Similitud: 0.847153)
#
# ==================================================
# 🔎 Procesando artista: **STARSET**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Starset
# Biografía (Resumen): Starset is an American alternative rock band formed in 2013 in Columbus, Ohio, by lead vocalist and Downplay former member Dustin Bates
#
# The current lineup consistst of: Dustin Bates (lead vocals, keyboards, piano, synths and guitars), Ron DeChant (bass, keyboards and backing vocals), Brock Richards (guitars and backing vocals) and Adam Gilbert (drums and percussion).
#
# They released their debut studio album, Transmissions, in 2014 with the label Razor & Tie, followed by a second studio album, Vessels, in 2017.
# Playcount Total (Last.fm): 25650655
# Número de Oyentes Únicos: 506981
#
# --- ARTISTAS SIMILARES ---
# 1. Downplay (Similitud: 1)
# 2. Written by Wolves (Similitud: 0.464372)
# 3. Red (Similitud: 0.448712)
# 4. Project Vela (Similitud: 0.406511)
# 5. Breaking Benjamin (Similitud: 0.396810)
#
# ==================================================
# 🔎 Procesando artista: **Lil Darkie**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Lil Darkie
# Biografía (Resumen): Joshua Hamilton also known as his stage name "Lil Darkie'' is a rapper, producer, and artist from Long Beach, California.
#
# He formally went as "Brahman" with a blue character, as he believed the Indian god Kali Ma was blue, after realizing that Kali Ma is portrayed with black skin, he rebranded as Lil Darkie and changed his sound alongside with the new persona. The Brahman period lasted a significant amount of time and even had a Collective before the Collective he has as Darkie named "Spider Gang"
# Playcount Total (Last.fm): 51877081
# Número de Oyentes Únicos: 667970
#
# --- ARTISTAS SIMILARES ---
# 1. Spider Gang (Similitud: 1)
# 2. Afourteen (Similitud: 0.866300)
# 3. ISSBROKIE (Similitud: 0.514128)
# 4. GODHANDUSA (Similitud: 0.499019)
# 5. Mkultra (Similitud: 0.496826)
#
# ==================================================
# 🔎 Procesando artista: **Scarlxrd**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: SCARLXRD
# Biografía (Resumen): Marius Listhrop (born 19 June 1994), known professionally as Scarlxrd (pronounced "scarlord"), is a English musician. He is known for his unusual musical style combining elements of trap music with influences from metal music. Formerly a YouTube personality known as Mazzi Maz, Scarlxrd began a career in music as the lead vocalist for nu metal band Myth City, before debuting as a rapper under his Scarlxrd moniker.
#
# By February 2017, Listhrop removed
# Playcount Total (Last.fm): 17369693
# Número de Oyentes Únicos: 322447
#
# --- ARTISTAS SIMILARES ---
# 1. PRXJEK (Similitud: 1)
# 2. BvdLvd (Similitud: 0.806399)
# 3. Kamiyada+ (Similitud: 0.770189)
# 4. Jasiah (Similitud: 0.756511)
# 5. nascar aloe (Similitud: 0.607071)
#
# ==================================================
# 🔎 Procesando artista: **Memphis May Fire**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: Memphis May Fire
# Biografía (Resumen): Memphis May Fire is a metalcore band with southern rock influences (previously post-hardcore) currently based in Dallas, Texas. The band formed in December 2006, but it was not until February 2007 that the group decided on the name Memphis May Fire having previously gone by "O Captain, My Captain!". Since its formation, the band has released two EPs and six full-length albums, the latest being Shapeshifter which was released in March 2025.
#
# In early 2007, the band recorded and self-released an EP, and began creating a local following.
# Playcount Total (Last.fm): 20878954
# Número de Oyentes Únicos: 518819
#
# --- ARTISTAS SIMILARES ---
# 1. Wage War (Similitud: 1)
# 2. We Came as Romans (Similitud: 0.873518)
# 3. Fit For A King (Similitud: 0.780292)
# 4. Of Mice & Men (Similitud: 0.719740)
# 5. Until i Wake (Similitud: 0.716307)
#
# ==================================================
# 🔎 Procesando artista: **In Flames**
# ==================================================
# --- BIOGRAFÍA y ESTADÍSTICAS ---
# Nombre: In Flames
# Biografía (Resumen): In Flames is a Swedish metal band, formed by guitarist Jesper Strömblad in Gothenburg in 1990 out of the Swedish death metal scene. Their lineup has changed several times, with vocalist Anders Fridén and guitarist Björn Gelotte being the only consistent members since 1995. Since the departure of Strömblad in 2010, no original members remain with the band. In Flames helped pioneer melodic death metal along with fellow Swedish bands At the Gates and Dark Tranquillity. The band has sold over two million records worldwide.
# Playcount Total (Last.fm): 194236096
# Número de Oyentes Únicos: 1575911
#
# --- ARTISTAS SIMILARES ---
# 1. Soilwork (Similitud: 1)
# 2. Dark Tranquillity (Similitud: 0.884285)
# 3. The Halo Effect (Similitud: 0.710741)
# 4. Arch Enemy (Similitud: 0.613769)
# 5. Insomnium (Similitud: 0.613724)
# Datos guardados en 'datos_artistas_lastfm.csv'
# Columnas guardadas: ['artista', 'playcount', 'listeners', 'biografia_resumen', 'similares']
